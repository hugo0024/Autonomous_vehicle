# %% [markdown]
# # NVIDIA_CNN2
# Model with image size changed

# %%
import os
import fnmatch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from natsort import natsorted

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten,Dropout, BatchNormalization, Conv2D
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras import regularizers
from tensorflow_addons.metrics import RSquare
from imgaug import augmenters as img_aug

import warnings
import random
import cv2
import pickle
warnings.filterwarnings('ignore')

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4096)]) # Notice here
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)

# %%
# Load csv file 
df = pd.read_csv('../datasets/PiCar/training_norm.csv', index_col=False)
df.head()
# Out:
#    image_id   angle  speed
# 0         1  0.4375    0.0
# 1         2  0.8125    1.0
# 2         3  0.4375    1.0
# 3         4  0.6250    1.0
# 4         5  0.5000    0.0

# %%
df.shape
# Out:
# (13793, 3)

# %%
#df = df.drop('image_id', axis=1)
#df.head()

# %%
df['angle'].value_counts()
# Out:
# 0.7500    2123
# 0.5000    2046
# 0.6875    2007
# 0.6250    1963
# 0.5625    1609
# 0.4375    1467
# 0.8125    1147
# 0.3750     428
# 0.8750     301
# 0.3125     213
# 0.2500     104
# 0.1250      99
# 0.1875      98
# 0.9375      65
# 0.0000      60
# 1.0000      35
# 0.0625      28
# Name: angle, dtype: int64

# %%
a = df['image_id'].tolist()
b = [x for x in range(a[0], a[-1] + 1)]
missing_vals = list(set(a) ^ set(b))
print('Missing data:', missing_vals)
# Out:
# Missing data: [3141, 3999, 4895, 8285, 10171]

# %%
images_dir = '../datasets/PiCar/train/training_data'
file_list = os.listdir(images_dir)
image_paths = []
pattern = "*.png"

for filename in file_list:
    if fnmatch.fnmatch(filename, pattern):
        image_paths.append(os.path.join(images_dir,filename))

image_paths = natsorted(image_paths)
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/3141.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/3999.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/4895.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/8285.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/10171.png']

image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\3141.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\3999.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\4895.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\8285.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\10171.png']

images = pd.DataFrame (image_paths, columns = ['images'])
images.describe()
# Out:
#                                                 images
# count                                            13793
# unique                                           13793
# top     ../datasets/PiCar/train/training_data/8925.png
# freq                                                 1

# %%
df_all = pd.concat([df, images], axis=1)
df_all = df_all.drop('image_id', axis=1)
df_all.tail()
# Out:
#         angle  speed                                           images
# 13788  0.6250    1.0  ../datasets/PiCar/train/training_data/13794.png
# 13789  0.4375    1.0  ../datasets/PiCar/train/training_data/13795.png
# 13790  0.5625    0.0  ../datasets/PiCar/train/training_data/13796.png
# 13791  0.6250    0.0  ../datasets/PiCar/train/training_data/13797.png
# 13792  0.6875    1.0  ../datasets/PiCar/train/training_data/13798.png

# %%
df_all.shape
# Out:
# (13793, 3)

# %%
#le = LabelEncoder()
#df_all['angle']= le.fit_transform(df_all['angle'])
#df_all.head()

# %%
image_paths = df_all['images'].tolist()
steering_angles = df_all['angle'].tolist()
speed = df_all['speed'].tolist()


image_index = 10
plt.imshow(Image.open(image_paths[image_index]))
print("image_path: %s" % image_paths[image_index]) 
print("steering_Angle:", steering_angles[image_index]) 
print("Speed:", speed[image_index])
# Out:
# image_path: ../datasets/PiCar/train/training_data/11.png
# steering_Angle: 0.6875
# Speed: 0.0

# %%
test_image = cv2.imread(df_all['images'][10])
test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)
print(test_image.shape)
test_image = cv2.resize(test_image, (240,180))
plt.imshow(test_image)
plt.show()
# Out:
# (240, 320, 3)

# %%
X_train, X_valid = train_test_split( df_all, test_size=0.2)
print("Training data: %d\nValidation data: %d" % (len(X_train), len(X_valid)))
# Out:
# Training data: 11034
# Validation data: 2759

# %%
class Nvidia_CNN2(tf.keras.Model):
  def __init__(self):
    super().__init__()
    
    self.conv1 = Conv2D(24, 5,strides=(2, 2), activation='relu')
    self.conv2 = Conv2D(36, 5, strides=(2, 2),activation='relu')
    self.conv3 = Conv2D(48, 5, strides=(2, 2),activation='relu')
    self.conv4 = Conv2D(64, 3, activation='relu') # stride taken out
    #self.drop1 = Dropout(0.25)
    self.batch1 = BatchNormalization()
    self.conv5 = Conv2D(64, 3,activation='relu')# stride taken out
    
    self.flatten = Flatten()
    self.drop2 = Dropout(0.25)
    self.d1 = Dense(100, activation='relu')
    self.d2 = Dense(50, activation='relu')
    self.d3 = Dense(10, activation='relu')
    #self.d4 = Dense(16, activation='relu')
    
    self.Y1 = Dense(1, activation='relu')    
    self.Y2 = Dense(1, activation = 'sigmoid')

  def call(self, x):
    x = self.conv1(x)
    x = self.conv2(x)
    x = self.conv3(x)
    x = self.conv4(x)
    #x = self.drop1(x)
    x = self.batch1(x)
    x = self.conv5(x)
    
    x = self.flatten(x)
    x = self.drop2(x)
    x = self.d1(x)
    x = self.d2(x)
    x = self.d3(x)
    #x = self.d4(x)
    
    
    y1 = self.Y1(x)
    y2 = self.Y2(x)
    
    return y1,y2

# %%
model = Nvidia_CNN2()
model.build((1,240, 180, 3))
model.summary()
# Out:
# Model: "nvidia_cnn2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             multiple                  1824
#
#  conv2d_1 (Conv2D)           multiple                  21636
#
#  conv2d_2 (Conv2D)           multiple                  43248
#
#  conv2d_3 (Conv2D)           multiple                  27712
#
#  batch_normalization (BatchN  multiple                 256
#  ormalization)
#
#  conv2d_4 (Conv2D)           multiple                  36928
#
#  flatten (Flatten)           multiple                  0
#
#  dropout (Dropout)           multiple                  0
#
#  dense (Dense)               multiple                  2208100
#
#  dense_1 (Dense)             multiple                  5050
#
#  dense_2 (Dense)             multiple                  510
#
#  dense_3 (Dense)             multiple                  11
#
#  dense_4 (Dense)             multiple                  11
#
# =================================================================
# Total params: 2,345,286
# Trainable params: 2,345,158
# Non-trainable params: 128
# _________________________________________________________________

# %%
def zoom(image):
    zoom = img_aug.Affine(scale=(1, 1.2))  # zoom from 100% (no zoom) to 120%
    image = zoom.augment_image(image)
    return image

def pan(image):
    # pan left / right / up / down about 10%
    pan = img_aug.Affine(translate_percent= {"x" : (-0.1, 0.1), "y": (-0.1, 0.1)})
    image = pan.augment_image(image)
    return image

def adjust_brightness(image):
    # increase or decrease brightness by 30%
    brightness = img_aug.Multiply((0.7, 1.3))
    image = brightness.augment_image(image)
    return image

def blur(image):
    kernel_size = random.randint(1, 3)  # kernel larger than 5 would make the image way too blurry
    image = cv2.blur(image,(kernel_size, kernel_size))
    return image

def random_augment(image):
    if np.random.rand() < 0.5:
        image = pan(image)
    if np.random.rand() < 0.5:
        image = zoom(image)
    if np.random.rand() < 0.5:
        image = blur(image)
    if np.random.rand() < 0.5:
        image = adjust_brightness(image)
    return image

# %%
def random_flip(image):
    is_flip = random.randint(0, 1)
    if is_flip == 1:
        image = cv2.flip(image,1)
    return image, is_flip

# %%
def custom_generator(df, batch_size, target_size, is_training):
    while True:
        # Shuffle the data
        df = df.sample(frac=1).reset_index(drop=True)
        for i in range(0, len(df), batch_size):
            batch = df[i:i+batch_size]
            # Load images and labels
            images = []
            angles = []
            speeds = []
            for _, row in batch.iterrows():
                img = cv2.imread(row['images'])
                angle = row['angle']
                speed = row['speed']

                if is_training:
                    img = random_augment(img)
                    img, is_flip = random_flip(img)
                    if is_flip:
                        angle = 1 - angle

                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, target_size)

                images.append(img)
                angles.append(angle)
                speeds.append(speed)

            # Normalize images
            images = np.array(images) / 255.0
            # Convert labels to arrays
            angles = np.array(angles)
            speeds = np.array(speeds)
            yield images, {'output_1': angles, 'output_2': speeds}

# %%
tf.keras.backend.clear_session()

# Early stop added
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

train_gen = custom_generator(X_train, batch_size=32 ,target_size=(240, 180), is_training= True)
val_gen = custom_generator(X_valid, batch_size=32, target_size=(240, 180), is_training= False)

model = Nvidia_CNN2()

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                       loss={
        "output_1" : tf.keras.losses.MeanSquaredError(),
        "output_2" : tf.keras.losses.BinaryCrossentropy(from_logits=False)},
        metrics={"output_1": 'mse', "output_2": 'accuracy'})


history = model.fit(train_gen,
                    steps_per_epoch=len(X_train) // 32,
                    validation_data=val_gen,
                    validation_steps=len(X_valid) // 32,
                    callbacks=[callback],
                    epochs=80)

model.save('model/Nvidia_CNN2',save_format='tf')

history_path = os.path.join('history.pickle')
with open(history_path, 'wb') as f:
    pickle.dump(history.history, f, pickle.HIGHEST_PROTOCOL)
# Out:
# Epoch 1
80
# 344/344 [==============================] - 77s 224ms/step - loss: 0.0598 - output_1_loss: 0.0099 - output_2_loss: 0.0500 - output_1_mse: 0.0099 - output_2_accuracy: 0.9815 - val_loss: 0.0727 - val_output_1_loss: 0.0093 - val_output_2_loss: 0.0634 - val_output_1_mse: 0.0093 - val_output_2_accuracy: 0.9753
# Epoch 42/80
# 344/344 [==============================] - 77s 224ms/step - loss: 0.0598 - output_1_loss: 0.0105 - output_2_loss: 0.0494 - output_1_mse: 0.0105 - output_2_accuracy: 0.9806 - val_loss: 0.1736 - val_output_1_loss: 0.0123 - val_output_2_loss: 0.1613 - val_output_1_mse: 0.0123 - val_output_2_accuracy: 0.9608
# Epoch 43/80
# 344/344 [==============================] - 77s 224ms/step - loss: 0.0574 - output_1_loss: 0.0101 - output_2_loss: 0.0473 - output_1_mse: 0.0101 - output_2_accuracy: 0.9825 - val_loss: 0.0911 - val_output_1_loss: 0.0137 - val_output_2_loss: 0.0774 - val_output_1_mse: 0.0137 - val_output_2_accuracy: 0.9749
# Epoch 44/80
# 344/344 [==============================] - 77s 225ms/step - loss: 0.0583 - output_1_loss: 0.0100 - output_2_loss: 0.0483 - output_1_mse: 0.0100 - output_2_accuracy: 0.9822 - val_loss: 0.0804 - val_output_1_loss: 0.0191 - val_output_2_loss: 0.0614 - val_output_1_mse: 0.0191 - val_output_2_accuracy: 0.9757
# Epoch 45/80
# 344/344 [==============================] - 77s 224ms/step - loss: 0.0581 - output_1_loss: 0.0102 - output_2_loss: 0.0479 - output_1_mse: 0.0102 - output_2_accuracy: 0.9809 - val_loss: 0.0657 - val_output_1_loss: 0.0113 - val_output_2_loss: 0.0544 - val_output_1_mse: 0.0113 - val_output_2_accuracy: 0.9775
# Epoch 46/80
# 344/344 [==============================] - 77s 224ms/step - loss: 0.0546 - output_1_loss: 0.0100 - output_2_loss: 0.0446 - output_1_mse: 0.0100 - output_2_accuracy: 0.9846 - val_loss: 0.0902 - val_output_1_loss: 0.0097 - val_output_2_loss: 0.0805 - val_output_1_mse: 0.0097 - val_output_2_accuracy: 0.9720
# Epoch 47/80
# 344/344 [==============================] - 77s 223ms/step - loss: 0.0575 - output_1_loss: 0.0098 - output_2_loss: 0.0478 - output_1_mse: 0.0098 - output_2_accuracy: 0.9844 - val_loss: 0.0760 - val_output_1_loss: 0.0113 - val_output_2_loss: 0.0647 - val_output_1_mse: 0.0113 - val_output_2_accuracy: 0.9749
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model/Nvidia_CNN2/assets
# INFO:tensorflow:Assets written to: model/Nvidia_CNN2/assets

# %%
history_path = os.path.join('history.pickle')
with open(history_path, 'rb') as f:
    history = pickle.load(f)

def plots(history):
    # summarize history for accuracy
    fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(2, 2, sharex=True, figsize=(10,6))
    
    ax1.set_title('Angle Loss')
    ax1.plot(history['output_1_loss'])
    ax1.plot(history['val_output_1_mse'])
    ax1.set_yscale('log')
    ax1.legend(['train', 'test'], loc='lower right')
    
    ax2.set_title('Speed Accuracy')
    ax2.plot(history['output_2_accuracy'])
    ax2.plot(history['val_output_2_accuracy'])
    ax2.set_yscale('log')
    ax2.legend(['train', 'test'], loc='lower right')
    
    # summarize history for loss
    ax3.set_title('Angle MSE loss')  
    ax3.plot(history['output_1_loss'])
    ax3.plot(history['val_output_1_loss'])
    ax3.set_yscale('log')
    ax3.legend(['train', 'test'], loc='upper right')
   
    ax4.set_title('Speed loss')
    ax4.plot(history['output_2_loss'])
    ax4.plot(history['val_output_2_loss'])
    ax4.set_yscale('log')
    ax4.legend(['train', 'test'], loc='upper right')
    plt.show()
    
    
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
plots(history)

# %% [markdown]
# # Evaluation using validation set

# %%
def validation_generator(df, batch_size, target_size):
    while True:

        for i in range(0, len(df), batch_size):
            batch = df
            # Load images and labels
            images = []
            for _, row in batch.iterrows():
                img = cv2.imread(row['images'])
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, target_size)
                images.append(img)

            images = np.array(images) / 255.0

            yield images

# %%
from keras.models import load_model
model = load_model('model/Nvidia_CNN2')
valgen = next(validation_generator(X_valid, batch_size=2759, target_size=(240, 180)))
predict = model.predict(valgen)
print(predict)
# Out:
# 87/87 [==============================] - 3s 36ms/step
# (array([[0.5635204 ],
#        [0.59411305],
#        [0.6022187 ],
#        ...,
#        [0.6770368 ],
#        [0.7039185 ],
#        [0.6255893 ]], dtype=float32), array([[0.99362946],
#        [0.94943506],
#        [0.8907593 ],
#        ...,
#        [0.9923173 ],
#        [0.99999166],
#        [0.99994135]], dtype=float32))

# %%
angles = pd.DataFrame(predict[0], columns=['angle'])
speed = pd.DataFrame(predict[1], columns=['speed'])
pred_df = pd.concat([angles, speed],axis=1)
pred_df.insert(0,"image_id", np.arange(1,len(pred_df)+1))

pred_df.head()
# Out:
#    image_id     angle     speed
# 0         1  0.563520  0.993629
# 1         2  0.594113  0.949435
# 2         3  0.602219  0.890759
# 3         4  0.579435  0.000028
# 4         5  0.473789  1.000000

# %%
pred_df.shape
# Out:
# (2759, 3)

# %% [markdown]
# ### MSE before round

# %%
mse = tf.keras.losses.MeanSquaredError()
angle_mse = mse(X_valid['angle'], pred_df['angle']).numpy()
speed_mse = mse(X_valid['speed'], pred_df['speed']).numpy()
print(f'mse angle: {angle_mse}\nmse speed: {speed_mse}')
# Out:
# mse angle: 0.011317694559693336
# mse speed: 0.018905388191342354

# %%
total_mse = angle_mse + speed_mse
print(f'Total mse: {total_mse}')
# Out:
# Total mse: 0.03022308275103569

# %%
pred_df_rnd = pred_df.round({'angle': 4,'speed': 0})
pred_df_rnd.head()
# Out:
#    image_id   angle  speed
# 0         1  0.5635    1.0
# 1         2  0.5941    1.0
# 2         3  0.6022    1.0
# 3         4  0.5794    0.0
# 4         5  0.4738    1.0

# %%
angle_mse = mse(X_valid['angle'], pred_df_rnd['angle']).numpy()
speed_mse = mse(X_valid['speed'], pred_df_rnd['speed']).numpy()
print(f'mse angle: {angle_mse}\nmse speed: {speed_mse}')
# Out:
# mse angle: 0.011317468248307705
# mse speed: 0.02471318282186985

# %%
total_mse = angle_mse + speed_mse
print(f'Total mse: {total_mse}')
# Out:
# Total mse: 0.03603065013885498

# %%
pred_df_rnd['speed'] = pd.to_numeric(pred_df_rnd['speed'],downcast="integer" )
pred_df_rnd.head()
# Out:
#    image_id   angle  speed
# 0         1  0.5635      1
# 1         2  0.5941      1
# 2         3  0.6022      1
# 3         4  0.5794      0
# 4         5  0.4738      1

# %%
X_valid['speed']=X_valid['speed'].astype("int")
X_valid.head()
# Out:
#        angle  speed                                           images
# 414    0.500      1    ../datasets/PiCar/train/training_data/415.png
# 3067   0.500      0   ../datasets/PiCar/train/training_data/3068.png
# 12098  0.500      1  ../datasets/PiCar/train/training_data/12104.png
# 13302  0.625      0  ../datasets/PiCar/train/training_data/13308.png
# 7593   0.500      1   ../datasets/PiCar/train/training_data/7597.png

# %%
cm = confusion_matrix(X_valid['speed'], pred_df_rnd['speed'])

# %%
# Plot confusion matrix
fig, ax = plt.subplots(figsize=(3,3))
ax.matshow(cm, cmap=plt.cm.Blues, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i, s=cm[i,j], va='center', ha='center')
classes=["1", "0"]
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)
plt.xlabel('Predicted Values',)
plt.ylabel('actual Values',);
print(classification_report(X_valid['speed'], pred_df_rnd['speed']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       641
#            1       0.98      0.98      0.98      2118
#
#     accuracy                           0.98      2759
#    macro avg       0.97      0.97      0.97      2759
# weighted avg       0.98      0.98      0.98      2759

# %%
# Plot the rciever opertaing characteristic curve (ROC)
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(10,8))
#probas_ = model.predict(X_valid['speed'])
fpr, tpr, thresholds = roc_curve(X_valid['speed'], pred_df['speed'])
roc_auc = auc(fpr,tpr)
plt.plot(fpr,tpr, lw=1, label='ROC fold (area = %0.2f)' %(roc_auc))
plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6), label='Random')
plt.xlim([-0.05,1.05])
plt.ylim([-0.05,1.05])
plt.xlabel('False positive rate | 1 - specificity (1 -  recall)')
plt.ylabel('True positive rate | Sensitivity ( recall)')
plt.title('Reciever operating characteristics')
plt.legend(loc="lower right")
plt.axes().set_aspect(1);

# %% [markdown]
# # Testing

# %%
images_dir = '../datasets/PiCar/test'
file_list = os.listdir(images_dir)
image_paths = []
pattern = "*.png"

for filename in file_list:
    if fnmatch.fnmatch(filename, pattern):
        image_paths.append(os.path.join(images_dir,filename))

image_paths = natsorted(image_paths)

images = pd.DataFrame (image_paths, columns = ['images'])
images.describe()
# Out:
#                               images
# count                           1020
# unique                          1020
# top     ../datasets/PiCar/test\1.png
# freq                               1

# %%
def test_generator(df, batch_size, target_size):
    while True:

        for i in range(0, len(df), batch_size):
            batch = df
            # Load images and labels
            images = []
            for _, row in batch.iterrows():
                img = cv2.imread(row['images'])
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, target_size)
                images.append(img)

            images = np.array(images) / 255.0

            yield images

# %%
from keras.models import load_model
model = load_model('model/Nvidia_CNN')
testgen = next(test_generator(images, batch_size=1020, target_size=(240, 120)))
predict = model.predict(testgen)
print(predict)
# Out:
# 32/32 [==============================] - 5s 8ms/step
# (array([[0.57233447],
#        [0.7269628 ],
#        [0.24392101],
#        ...,
#        [0.4193011 ],
#        [0.48417288],
#        [0.2161816 ]], dtype=float32), array([[0.00648858],
#        [1.        ],
#        [0.9712993 ],
#        ...,
#        [0.9992417 ],
#        [0.80309635],
#        [0.9901134 ]], dtype=float32))

# %%
angles = pd.DataFrame(predict[0], columns=['Angle'])
speed = pd.DataFrame(predict[1], columns=['speed'])
pred_df = pd.concat([angles, speed],axis=1)
pred_df.insert(0,"image_id", np.arange(1,len(pred_df)+1))

pred_df.head()
# Out:
#    image_id     Angle     speed
# 0         1  0.572334  0.006489
# 1         2  0.726963  1.000000
# 2         3  0.243921  0.971299
# 3         4  0.231288  0.998323
# 4         5  0.231272  0.947584

# %%
pred_df = pred_df.round({'Angle': 4, 'speed': 0})
pred_df.head()
# Out:
#    image_id   Angle  speed
# 0         1  0.5723    0.0
# 1         2  0.7270    1.0
# 2         3  0.2439    1.0
# 3         4  0.2313    1.0
# 4         5  0.2313    1.0

# %%
pred_df.to_csv('Tow_mat4.csv', index=False)

# %%
test = next(custom_generator(X_valid, batch_size=10, target_size=(240, 120), is_training=False))

# %%
predict_test = model.predict(test[0])
# Out:
# 1/1 [==============================] - 0s 18ms/step

# %%
print(predict_test[0])
# Out:
# [[0.5511235 ]
#  [0.7568309 ]
#  [0.7777829 ]
#  [0.72114545]
#  [0.4993554 ]
#  [0.54714364]
#  [0.47722927]
#  [0.5665439 ]
#  [0.6199493 ]
#  [0.7158552 ]]

# %%
print(test[1])
# Out:
# {'output_1': array([0.625 , 0.75  , 0.6875, 0.6875, 0.5   , 0.5   , 0.5   , 0.5625,
#        0.625 , 0.6875]), 'output_2': array([1., 1., 0., 0., 1., 1., 1., 0., 1., 0.])}
