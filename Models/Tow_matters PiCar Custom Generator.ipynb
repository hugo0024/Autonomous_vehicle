# %% [markdown]
# # Tow_matters PiCar

# %%
import os
import fnmatch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from natsort import natsorted

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten,Dropout, BatchNormalization, Conv2D
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras import regularizers
from tensorflow_addons.metrics import RSquare
from imgaug import augmenters as img_aug

import warnings
import random
import cv2
import pickle
warnings.filterwarnings('ignore')

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4096)]) # Notice here
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# Load csv file 
df = pd.read_csv('../datasets/PiCar/training_norm.csv', index_col=False)
df.head()
# Out:
#    image_id   angle  speed
# 0         1  0.4375    0.0
# 1         2  0.8125    1.0
# 2         3  0.4375    1.0
# 3         4  0.6250    1.0
# 4         5  0.5000    0.0

# %%
df.shape
# Out:
# (13793, 3)

# %%
#df = df.drop('image_id', axis=1)
#df.head()

# %%
df['angle'].value_counts()
# Out:
# 0.7500    2123
# 0.5000    2046
# 0.6875    2007
# 0.6250    1963
# 0.5625    1609
# 0.4375    1467
# 0.8125    1147
# 0.3750     428
# 0.8750     301
# 0.3125     213
# 0.2500     104
# 0.1250      99
# 0.1875      98
# 0.9375      65
# 0.0000      60
# 1.0000      35
# 0.0625      28
# Name: angle, dtype: int64

# %%
a = df['image_id'].tolist()
b = [x for x in range(a[0], a[-1] + 1)]
missing_vals = list(set(a) ^ set(b))
print('Missing data:', missing_vals)
# Out:
# Missing data: [3141, 3999, 4895, 8285, 10171]

# %%
images_dir = '../datasets/PiCar/train/training_data'
file_list = os.listdir(images_dir)
image_paths = []
pattern = "*.png"

for filename in file_list:
    if fnmatch.fnmatch(filename, pattern):
        image_paths.append(os.path.join(images_dir,filename))

image_paths = natsorted(image_paths)
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/3141.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/3999.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/4895.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/8285.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/10171.png']

image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\3141.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\3999.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\4895.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\8285.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\10171.png']

images = pd.DataFrame (image_paths, columns = ['images'])
images.describe()
# Out:
#                                              images
# count                                         13793
# unique                                        13793
# top     ../datasets/PiCar/train/training_data\1.png
# freq                                              1

# %%
df_all = pd.concat([df, images], axis=1)
df_all = df_all.drop('image_id', axis=1)
df_all.tail()
# Out:
#         angle  speed                                           images
# 13788  0.6250    1.0  ../datasets/PiCar/train/training_data\13794.png
# 13789  0.4375    1.0  ../datasets/PiCar/train/training_data\13795.png
# 13790  0.5625    0.0  ../datasets/PiCar/train/training_data\13796.png
# 13791  0.6250    0.0  ../datasets/PiCar/train/training_data\13797.png
# 13792  0.6875    1.0  ../datasets/PiCar/train/training_data\13798.png

# %%
df_all.shape
# Out:
# (13793, 3)

# %%
#le = LabelEncoder()
#df_all['angle']= le.fit_transform(df_all['angle'])
#df_all.head()

# %%
image_paths = df_all['images'].tolist()
steering_angles = df_all['angle'].tolist()
speed = df_all['speed'].tolist()


image_index = 10
plt.imshow(Image.open(image_paths[image_index]))
print("image_path: %s" % image_paths[image_index]) 
print("steering_Angle:", steering_angles[image_index]) 
print("Speed:", speed[image_index])
# Out:
# image_path: ../datasets/PiCar/train/training_data\11.png
# steering_Angle: 0.6875
# Speed: 0.0

# %%
test_image = cv2.imread(df_all['images'][6])
test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)
print(test_image.shape)
test_image = cv2.resize(test_image, (240,120))
plt.imshow(test_image)
plt.show()
# Out:
# (240, 320, 3)

# %%
X_train, X_valid = train_test_split( df_all, test_size=0.2)
print("Training data: %d\nValidation data: %d" % (len(X_train), len(X_valid)))
# Out:
# Training data: 11034
# Validation data: 2759

# %%
class Nvidia_CNN(tf.keras.Model):
  def __init__(self):
    super().__init__()
    
    self.conv1 = Conv2D(24, 5,strides=(2, 2), activation='relu')
    self.conv2 = Conv2D(36, 5, strides=(2, 2),activation='relu')
    self.conv3 = Conv2D(48, 5, strides=(2, 2),activation='relu')
    self.conv4 = Conv2D(64, 3, strides=(2, 2), activation='relu')
    self.drop1 = Dropout(0.25)
    self.conv5 = Conv2D(64, 3, strides=(2, 2),activation='relu')
    
    self.flatten = Flatten()
    self.drop2 = Dropout(0.25)
    self.d1 = Dense(128, activation='relu')
    self.d2 = Dense(64, activation='relu')
    self.d3 = Dense(32, activation='relu')
    #self.d4 = Dense(16, activation='relu')
    
    self.Y1 = Dense(1, activation='relu')    
    self.Y2 = Dense(1, activation = 'sigmoid')

  def call(self, x):
    x = self.conv1(x)
    x = self.conv2(x)
    x = self.conv3(x)
    x = self.conv4(x)
    x = self.drop1(x)
    x = self.conv5(x)
    
    x = self.flatten(x)
    x = self.drop2(x)
    x = self.d1(x)
    x = self.d2(x)
    x = self.d3(x)
    #x = self.d4(x)
    
    
    y1 = self.Y1(x)
    y2 = self.Y2(x)
    
    return y1,y2

# %%
def zoom(image):
    zoom = img_aug.Affine(scale=(1, 1.2))  # zoom from 100% (no zoom) to 120%
    image = zoom.augment_image(image)
    return image

def pan(image):
    # pan left / right / up / down about 10%
    pan = img_aug.Affine(translate_percent= {"x" : (-0.1, 0.1), "y": (-0.1, 0.1)})
    image = pan.augment_image(image)
    return image

def adjust_brightness(image):
    # increase or decrease brightness by 30%
    brightness = img_aug.Multiply((0.7, 1.3))
    image = brightness.augment_image(image)
    return image

def blur(image):
    kernel_size = random.randint(1, 3)  # kernel larger than 5 would make the image way too blurry
    image = cv2.blur(image,(kernel_size, kernel_size))
    return image

def random_augment(image):
    if np.random.rand() < 0.5:
        image = pan(image)
    if np.random.rand() < 0.5:
        image = zoom(image)
    if np.random.rand() < 0.5:
        image = blur(image)
    if np.random.rand() < 0.5:
        image = adjust_brightness(image)
    return image

# %%
def random_flip(image):
    is_flip = random.randint(0, 1)
    if is_flip == 1:
        image = cv2.flip(image,1)
    return image, is_flip

# %%
def custom_generator(df, batch_size, target_size, is_training):
    while True:
        # Shuffle the data
        df = df.sample(frac=1).reset_index(drop=True)
        for i in range(0, len(df), batch_size):
            batch = df[i:i+batch_size]
            # Load images and labels
            images = []
            angles = []
            speeds = []
            for _, row in batch.iterrows():
                img = cv2.imread(row['images'])
                angle = row['angle']
                speed = row['speed']

                if is_training:
                    img = random_augment(img)
                    img, is_flip = random_flip(img)
                    if is_flip:
                        angle = 1 - angle

                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, target_size)

                images.append(img)
                angles.append(angle)
                speeds.append(speed)

            # Normalize images
            images = np.array(images) / 255.0
            # Convert labels to arrays
            angles = np.array(angles)
            speeds = np.array(speeds)
            yield images, {'output_1': angles, 'output_2': speeds}

# %%
tf.keras.backend.clear_session()

# Early stop added
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

train_gen = custom_generator(X_train, batch_size=32 ,target_size=(240, 120), is_training= True)
val_gen = custom_generator(X_valid, batch_size=32, target_size=(240, 120), is_training= False)

model = Nvidia_CNN()

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                       loss={
        "output_1" : tf.keras.losses.MeanSquaredError(),
        "output_2" : tf.keras.losses.BinaryCrossentropy(from_logits=False)},
        metrics={"output_1": [RSquare()], "output_2": 'accuracy'})


history = model.fit(train_gen,
                    steps_per_epoch=len(X_train) // 32,
                    validation_data=val_gen,
                    validation_steps=len(X_valid) // 32,
                    callbacks=[callback],
                    epochs=80)

model.save('model/Nvidia_CNN',save_format='tf')

history_path = os.path.join('history.pickle')
with open(history_path, 'wb') as f:
    pickle.dump(history.history, f, pickle.HIGHEST_PROTOCOL)
# Out:
# Epoch 1/80
# 344/344 [==============================] - 51s 143ms/step - loss: 0.6056 - output_1_loss: 0.0450 - output_2_loss: 0.5606 - output_1_r_square: -0.2701 - output_2_accuracy: 0.7455 - val_loss: 0.5647 - val_output_1_loss: 0.0361 - val_output_2_loss: 0.5286 - val_output_1_r_square: -0.5245 - val_output_2_accuracy: 0.7515
# Epoch 2/80
# 344/344 [==============================] - 42s 121ms/step - loss: 0.5047 - output_1_loss: 0.0332 - output_2_loss: 0.4715 - output_1_r_square: 0.0630 - output_2_accuracy: 0.7704 - val_loss: 0.3592 - val_output_1_loss: 0.0264 - val_output_2_loss: 0.3328 - val_output_1_r_square: -0.1080 - val_output_2_accuracy: 0.8648
# Epoch 3/80
# 344/344 [==============================] - 45s 130ms/step - loss: 0.3576 - output_1_loss: 0.0275 - output_2_loss: 0.3300 - output_1_r_square: 0.2236 - output_2_accuracy: 0.8622 - val_loss: 0.2920 - val_output_1_loss: 0.0196 - val_output_2_loss: 0.2724 - val_output_1_r_square: 0.1701 - val_output_2_accuracy: 0.9095
# Epoch 4/80
# 344/344 [==============================] - 45s 132ms/step - loss: 0.2556 - output_1_loss: 0.0256 - output_2_loss: 0.2300 - output_1_r_square: 0.2758 - output_2_accuracy: 0.9172 - val_loss: 0.2119 - val_output_1_loss: 0.0233 - val_output_2_loss: 0.1886 - val_output_1_r_square: 0.0217 - val_output_2_accuracy: 0.9339
# Epoch 5/80
# 344/344 [==============================] - 45s 131ms/step - loss: 0.2130 - output_1_loss: 0.0225 - output_2_loss: 0.1905 - output_1_r_square: 0.3630 - output_2_accuracy: 0.9338 - val_loss: 0.1713 - val_output_1_loss: 0.0174 - val_output_2_loss: 0.1539 - val_output_1_r_square: 0.2701 - val_output_2_accuracy: 0.9448
# Epoch 6/80
# 344/344 [==============================] - 43s 126ms/step - loss: 0.1985 - output_1_loss: 0.0210 - output_2_loss: 0.1775 - output_1_r_square: 0.4075 - output_2_accuracy: 0.9354 - val_loss: 0.1634 - val_output_1_loss: 0.0199 - val_output_2_loss: 0.1436 - val_output_1_r_square: 0.1619 - val_output_2_accuracy: 0.9499
# Epoch 7/80
# 344/344 [==============================] - 42s 123ms/step - loss: 0.1894 - output_1_loss: 0.0199 - output_2_loss: 0.1696 - output_1_r_square: 0.4385 - output_2_accuracy: 0.9376 - val_loss: 0.1461 - val_output_1_loss: 0.0175 - val_output_2_loss: 0.1287 - val_output_1_r_square: 0.2669 - val_output_2_accuracy: 0.9528
# Epoch 8/80
# 344/344 [==============================] - 44s 129ms/step - loss: 0.1766 - output_1_loss: 0.0188 - output_2_loss: 0.1577 - output_1_r_square: 0.4693 - output_2_accuracy: 0.9425 - val_loss: 0.1352 - val_output_1_loss: 0.0138 - val_output_2_loss: 0.1214 - val_output_1_r_square: 0.4178 - val_output_2_accuracy: 0.9539
# Epoch 9/80
# 344/344 [==============================] - 43s 125ms/step - loss: 0.1685 - output_1_loss: 0.0180 - output_2_loss: 0.1505 - output_1_r_square: 0.4916 - output_2_accuracy: 0.9437 - val_loss: 0.1318 - val_output_1_loss: 0.0134 - val_output_2_loss: 0.1184 - val_output_1_r_square: 0.4382 - val_output_2_accuracy: 0.9539
# Epoch 10/80
# 344/344 [==============================] - 43s 125ms/step - loss: 0.1620 - output_1_loss: 0.0175 - output_2_loss: 0.1446 - output_1_r_square: 0.5077 - output_2_accuracy: 0.9456 - val_loss: 0.1261 - val_output_1_loss: 0.0139 - val_output_2_loss: 0.1122 - val_output_1_r_square: 0.4168 - val_output_2_accuracy: 0.9553
# Epoch 11/80
# 344/344 [==============================] - 42s 122ms/step - loss: 0.1581 - output_1_loss: 0.0171 - output_2_loss: 0.1410 - output_1_r_square: 0.5164 - output_2_accuracy: 0.9480 - val_loss: 0.1234 - val_output_1_loss: 0.0134 - val_output_2_loss: 0.1100 - val_output_1_r_square: 0.4377 - val_output_2_accuracy: 0.9557
# Epoch 12/80
# 344/344 [==============================] - 47s 137ms/step - loss: 0.1525 - output_1_loss: 0.0160 - output_2_loss: 0.1365 - output_1_r_square: 0.5493 - output_2_accuracy: 0.9484 - val_loss: 0.1270 - val_output_1_loss: 0.0146 - val_output_2_loss: 0.1125 - val_output_1_r_square: 0.3856 - val_output_2_accuracy: 0.9553
# Epoch 13/80
# 344/344 [==============================] - 45s 132ms/step - loss: 0.1490 - output_1_loss: 0.0157 - output_2_loss: 0.1333 - output_1_r_square: 0.5563 - output_2_accuracy: 0.9500 - val_loss: 0.1124 - val_output_1_loss: 0.0112 - val_output_2_loss: 0.1013 - val_output_1_r_square: 0.5300 - val_output_2_accuracy: 0.9586
# Epoch 14/80
# 344/344 [==============================] - 44s 129ms/step - loss: 0.1383 - output_1_loss: 0.0154 - output_2_loss: 0.1229 - output_1_r_square: 0.5637 - output_2_accuracy: 0.9525 - val_loss: 0.1256 - val_output_1_loss: 0.0125 - val_output_2_loss: 0.1131 - val_output_1_r_square: 0.4743 - val_output_2_accuracy: 0.9557
# Epoch 15/80
# 344/344 [==============================] - 45s 132ms/step - loss: 0.1424 - output_1_loss: 0.0152 - output_2_loss: 0.1272 - output_1_r_square: 0.5734 - output_2_accuracy: 0.9517 - val_loss: 0.1300 - val_output_1_loss: 0.0127 - val_output_2_loss: 0.1173 - val_output_1_r_square: 0.4671 - val_output_2_accuracy: 0.9517
# Epoch 16/80
# 344/344 [==============================] - 44s 128ms/step - loss: 0.1350 - output_1_loss: 0.0150 - output_2_loss: 0.1200 - output_1_r_square: 0.5759 - output_2_accuracy: 0.9527 - val_loss: 0.1098 - val_output_1_loss: 0.0112 - val_output_2_loss: 0.0986 - val_output_1_r_square: 0.5294 - val_output_2_accuracy: 0.9633
# Epoch 17/80
# 344/344 [==============================] - 43s 124ms/step - loss: 0.1307 - output_1_loss: 0.0141 - output_2_loss: 0.1165 - output_1_r_square: 0.5993 - output_2_accuracy: 0.9543 - val_loss: 0.1247 - val_output_1_loss: 0.0112 - val_output_2_loss: 0.1134 - val_output_1_r_square: 0.5280 - val_output_2_accuracy: 0.9466
# Epoch 18/80
# 344/344 [==============================] - 43s 124ms/step - loss: 0.1281 - output_1_loss: 0.0139 - output_2_loss: 0.1142 - output_1_r_square: 0.6095 - output_2_accuracy: 0.9563 - val_loss: 0.1036 - val_output_1_loss: 0.0138 - val_output_2_loss: 0.0898 - val_output_1_r_square: 0.4205 - val_output_2_accuracy: 0.9608
# Epoch 19/80
# 344/344 [==============================] - 43s 124ms/step - loss: 0.1216 - output_1_loss: 0.0135 - output_2_loss: 0.1081 - output_1_r_square: 0.6185 - output_2_accuracy: 0.9578 - val_loss: 0.1055 - val_output_1_loss: 0.0118 - val_output_2_loss: 0.0937 - val_output_1_r_square: 0.5033 - val_output_2_accuracy: 0.9582
# Epoch 20/80
# 344/344 [==============================] - 43s 124ms/step - loss: 0.1207 - output_1_loss: 0.0134 - output_2_loss: 0.1073 - output_1_r_square: 0.6217 - output_2_accuracy: 0.9582 - val_loss: 0.0964 - val_output_1_loss: 0.0098 - val_output_2_loss: 0.0866 - val_output_1_r_square: 0.5869 - val_output_2_accuracy: 0.9611
# Epoch 21/80
# 344/344 [==============================] - 43s 124ms/step - loss: 0.1151 - output_1_loss: 0.0132 - output_2_loss: 0.1018 - output_1_r_square: 0.6263 - output_2_accuracy: 0.9603 - val_loss: 0.0918 - val_output_1_loss: 0.0110 - val_output_2_loss: 0.0808 - val_output_1_r_square: 0.5403 - val_output_2_accuracy: 0.9684
# Epoch 22/80
# 344/344 [==============================] - 43s 124ms/step - loss: 0.1119 - output_1_loss: 0.0130 - output_2_loss: 0.0989 - output_1_r_square: 0.6332 - output_2_accuracy: 0.9623 - val_loss: 0.0945 - val_output_1_loss: 0.0102 - val_output_2_loss: 0.0843 - val_output_1_r_square: 0.5716 - val_output_2_accuracy: 0.9651
# Epoch 23/80
# 344/344 [==============================] - 43s 126ms/step - loss: 0.1177 - output_1_loss: 0.0128 - output_2_loss: 0.1049 - output_1_r_square: 0.6410 - output_2_accuracy: 0.9613 - val_loss: 0.0927 - val_output_1_loss: 0.0107 - val_output_2_loss: 0.0820 - val_output_1_r_square: 0.5497 - val_output_2_accuracy: 0.9666
# Epoch 24/80
# 344/344 [==============================] - 42s 122ms/step - loss: 0.1104 - output_1_loss: 0.0124 - output_2_loss: 0.0979 - output_1_r_square: 0.6510 - output_2_accuracy: 0.9617 - val_loss: 0.0868 - val_output_1_loss: 0.0096 - val_output_2_loss: 0.0772 - val_output_1_r_square: 0.5966 - val_output_2_accuracy: 0.9691
# Epoch 25/80
# 344/344 [==============================] - 44s 127ms/step - loss: 0.1054 - output_1_loss: 0.0123 - output_2_loss: 0.0931 - output_1_r_square: 0.6493 - output_2_accuracy: 0.9635 - val_loss: 0.0834 - val_output_1_loss: 0.0099 - val_output_2_loss: 0.0735 - val_output_1_r_square: 0.5846 - val_output_2_accuracy: 0.9706
# Epoch 26/80
# 344/344 [==============================] - 45s 130ms/step - loss: 0.1008 - output_1_loss: 0.0119 - output_2_loss: 0.0889 - output_1_r_square: 0.6627 - output_2_accuracy: 0.9644 - val_loss: 0.1137 - val_output_1_loss: 0.0094 - val_output_2_loss: 0.1043 - val_output_1_r_square: 0.6037 - val_output_2_accuracy: 0.9608
# Epoch 27/80
# 344/344 [==============================] - 44s 128ms/step - loss: 0.1003 - output_1_loss: 0.0117 - output_2_loss: 0.0885 - output_1_r_square: 0.6692 - output_2_accuracy: 0.9664 - val_loss: 0.0821 - val_output_1_loss: 0.0091 - val_output_2_loss: 0.0730 - val_output_1_r_square: 0.6160 - val_output_2_accuracy: 0.9713
# Epoch 28/80
# 344/344 [==============================] - 43s 126ms/step - loss: 0.1019 - output_1_loss: 0.0122 - output_2_loss: 0.0897 - output_1_r_square: 0.6561 - output_2_accuracy: 0.9644 - val_loss: 0.0904 - val_output_1_loss: 0.0111 - val_output_2_loss: 0.0792 - val_output_1_r_square: 0.5315 - val_output_2_accuracy: 0.9669
# Epoch 29/80
# 344/344 [==============================] - 45s 132ms/step - loss: 0.0939 - output_1_loss: 0.0117 - output_2_loss: 0.0822 - output_1_r_square: 0.6679 - output_2_accuracy: 0.9679 - val_loss: 0.0786 - val_output_1_loss: 0.0096 - val_output_2_loss: 0.0690 - val_output_1_r_square: 0.5977 - val_output_2_accuracy: 0.9702
# Epoch 30/80
# 344/344 [==============================] - 47s 136ms/step - loss: 0.0960 - output_1_loss: 0.0118 - output_2_loss: 0.0842 - output_1_r_square: 0.6666 - output_2_accuracy: 0.9676 - val_loss: 0.0840 - val_output_1_loss: 0.0092 - val_output_2_loss: 0.0748 - val_output_1_r_square: 0.6135 - val_output_2_accuracy: 0.9669
# Epoch 31/80
# 344/344 [==============================] - 45s 132ms/step - loss: 0.0950 - output_1_loss: 0.0116 - output_2_loss: 0.0834 - output_1_r_square: 0.6716 - output_2_accuracy: 0.9666 - val_loss: 0.0777 - val_output_1_loss: 0.0090 - val_output_2_loss: 0.0687 - val_output_1_r_square: 0.6202 - val_output_2_accuracy: 0.9735
# Epoch 32/80
# 344/344 [==============================] - 44s 127ms/step - loss: 0.0945 - output_1_loss: 0.0112 - output_2_loss: 0.0833 - output_1_r_square: 0.6849 - output_2_accuracy: 0.9660 - val_loss: 0.0857 - val_output_1_loss: 0.0092 - val_output_2_loss: 0.0765 - val_output_1_r_square: 0.6147 - val_output_2_accuracy: 0.9662
# Epoch 33/80
# 344/344 [==============================] - 43s 124ms/step - loss: 0.0919 - output_1_loss: 0.0117 - output_2_loss: 0.0802 - output_1_r_square: 0.6728 - output_2_accuracy: 0.9695 - val_loss: 0.0849 - val_output_1_loss: 0.0101 - val_output_2_loss: 0.0748 - val_output_1_r_square: 0.5767 - val_output_2_accuracy: 0.9684
# Epoch 34/80
# 344/344 [==============================] - 43s 127ms/step - loss: 0.0885 - output_1_loss: 0.0112 - output_2_loss: 0.0773 - output_1_r_square: 0.6828 - output_2_accuracy: 0.9700 - val_loss: 0.0815 - val_output_1_loss: 0.0084 - val_output_2_loss: 0.0731 - val_output_1_r_square: 0.6488 - val_output_2_accuracy: 0.9717
# Epoch 35/80
# 344/344 [==============================] - 43s 126ms/step - loss: 0.0925 - output_1_loss: 0.0111 - output_2_loss: 0.0813 - output_1_r_square: 0.6847 - output_2_accuracy: 0.9688 - val_loss: 0.0736 - val_output_1_loss: 0.0089 - val_output_2_loss: 0.0647 - val_output_1_r_square: 0.6267 - val_output_2_accuracy: 0.9749
# Epoch 36/80
# 344/344 [==============================] - 43s 124ms/step - loss: 0.0860 - output_1_loss: 0.0108 - output_2_loss: 0.0752 - output_1_r_square: 0.6929 - output_2_accuracy: 0.9700 - val_loss: 0.0787 - val_output_1_loss: 0.0083 - val_output_2_loss: 0.0704 - val_output_1_r_square: 0.6501 - val_output_2_accuracy: 0.9738
# Epoch 37/80
# 344/344 [==============================] - 42s 123ms/step - loss: 0.0859 - output_1_loss: 0.0112 - output_2_loss: 0.0747 - output_1_r_square: 0.6869 - output_2_accuracy: 0.9721 - val_loss: 0.0730 - val_output_1_loss: 0.0090 - val_output_2_loss: 0.0640 - val_output_1_r_square: 0.6222 - val_output_2_accuracy: 0.9767
# Epoch 38/80
# 344/344 [==============================] - 42s 123ms/step - loss: 0.0856 - output_1_loss: 0.0106 - output_2_loss: 0.0750 - output_1_r_square: 0.7002 - output_2_accuracy: 0.9715 - val_loss: 0.0725 - val_output_1_loss: 0.0092 - val_output_2_loss: 0.0634 - val_output_1_r_square: 0.6140 - val_output_2_accuracy: 0.9738
# Epoch 39/80
# 344/344 [==============================] - 42s 121ms/step - loss: 0.0830 - output_1_loss: 0.0108 - output_2_loss: 0.0723 - output_1_r_square: 0.6958 - output_2_accuracy: 0.9724 - val_loss: 0.0756 - val_output_1_loss: 0.0084 - val_output_2_loss: 0.0671 - val_output_1_r_square: 0.6458 - val_output_2_accuracy: 0.9742
# Epoch 40/80
# 344/344 [==============================] - 42s 122ms/step - loss: 0.0850 - output_1_loss: 0.0108 - output_2_loss: 0.0742 - output_1_r_square: 0.6944 - output_2_accuracy: 0.9720 - val_loss: 0.0695 - val_output_1_loss: 0.0094 - val_output_2_loss: 0.0601 - val_output_1_r_square: 0.6059 - val_output_2_accuracy: 0.9753
# Epoch 41/80
# 344/344 [==============================] - 42s 123ms/step - loss: 0.0800 - output_1_loss: 0.0105 - output_2_loss: 0.0695 - output_1_r_square: 0.7025 - output_2_accuracy: 0.9722 - val_loss: 0.0653 - val_output_1_loss: 0.0087 - val_output_2_loss: 0.0566 - val_output_1_r_square: 0.6348 - val_output_2_accuracy: 0.9757
# Epoch 42/80
# 344/344 [==============================] - 42s 122ms/step - loss: 0.0818 - output_1_loss: 0.0107 - output_2_loss: 0.0711 - output_1_r_square: 0.6972 - output_2_accuracy: 0.9725 - val_loss: 0.0693 - val_output_1_loss: 0.0086 - val_output_2_loss: 0.0607 - val_output_1_r_square: 0.6395 - val_output_2_accuracy: 0.9738
# Epoch 43/80
# 344/344 [==============================] - 42s 123ms/step - loss: 0.0832 - output_1_loss: 0.0107 - output_2_loss: 0.0725 - output_1_r_square: 0.7011 - output_2_accuracy: 0.9730 - val_loss: 0.0668 - val_output_1_loss: 0.0083 - val_output_2_loss: 0.0585 - val_output_1_r_square: 0.6521 - val_output_2_accuracy: 0.9778
# Epoch 44/80
# 344/344 [==============================] - 42s 123ms/step - loss: 0.0787 - output_1_loss: 0.0104 - output_2_loss: 0.0682 - output_1_r_square: 0.7061 - output_2_accuracy: 0.9735 - val_loss: 0.0732 - val_output_1_loss: 0.0082 - val_output_2_loss: 0.0650 - val_output_1_r_square: 0.6546 - val_output_2_accuracy: 0.9753
# Epoch 45/80
# 344/344 [==============================] - 42s 123ms/step - loss: 0.0830 - output_1_loss: 0.0104 - output_2_loss: 0.0725 - output_1_r_square: 0.7066 - output_2_accuracy: 0.9737 - val_loss: 0.0643 - val_output_1_loss: 0.0083 - val_output_2_loss: 0.0560 - val_output_1_r_square: 0.6532 - val_output_2_accuracy: 0.9797
# Epoch 46/80
# 344/344 [==============================] - 42s 121ms/step - loss: 0.0743 - output_1_loss: 0.0102 - output_2_loss: 0.0641 - output_1_r_square: 0.7121 - output_2_accuracy: 0.9755 - val_loss: 0.0682 - val_output_1_loss: 0.0082 - val_output_2_loss: 0.0600 - val_output_1_r_square: 0.6552 - val_output_2_accuracy: 0.9789
# Epoch 47/80
# 344/344 [==============================] - 41s 121ms/step - loss: 0.0751 - output_1_loss: 0.0107 - output_2_loss: 0.0644 - output_1_r_square: 0.6970 - output_2_accuracy: 0.9747 - val_loss: 0.0712 - val_output_1_loss: 0.0085 - val_output_2_loss: 0.0627 - val_output_1_r_square: 0.6432 - val_output_2_accuracy: 0.9757
# Epoch 48/80
# 344/344 [==============================] - 42s 122ms/step - loss: 0.0792 - output_1_loss: 0.0103 - output_2_loss: 0.0689 - output_1_r_square: 0.7109 - output_2_accuracy: 0.9742 - val_loss: 0.0622 - val_output_1_loss: 0.0087 - val_output_2_loss: 0.0535 - val_output_1_r_square: 0.6362 - val_output_2_accuracy: 0.9807
# Epoch 49/80
# 344/344 [==============================] - 41s 121ms/step - loss: 0.0769 - output_1_loss: 0.0104 - output_2_loss: 0.0665 - output_1_r_square: 0.7065 - output_2_accuracy: 0.9744 - val_loss: 0.0677 - val_output_1_loss: 0.0084 - val_output_2_loss: 0.0594 - val_output_1_r_square: 0.6480 - val_output_2_accuracy: 0.9782
# Epoch 50/80
# 344/344 [==============================] - 42s 121ms/step - loss: 0.0707 - output_1_loss: 0.0100 - output_2_loss: 0.0607 - output_1_r_square: 0.7169 - output_2_accuracy: 0.9778 - val_loss: 0.0600 - val_output_1_loss: 0.0081 - val_output_2_loss: 0.0519 - val_output_1_r_square: 0.6588 - val_output_2_accuracy: 0.9822
# Epoch 51/80
# 344/344 [==============================] - 42s 121ms/step - loss: 0.0733 - output_1_loss: 0.0100 - output_2_loss: 0.0633 - output_1_r_square: 0.7175 - output_2_accuracy: 0.9751 - val_loss: 0.0668 - val_output_1_loss: 0.0082 - val_output_2_loss: 0.0586 - val_output_1_r_square: 0.6559 - val_output_2_accuracy: 0.9764
# Epoch 52/80
# 344/344 [==============================] - 42s 123ms/step - loss: 0.0751 - output_1_loss: 0.0103 - output_2_loss: 0.0648 - output_1_r_square: 0.7101 - output_2_accuracy: 0.9758 - val_loss: 0.0615 - val_output_1_loss: 0.0078 - val_output_2_loss: 0.0537 - val_output_1_r_square: 0.6715 - val_output_2_accuracy: 0.9800
# Epoch 53/80
# 344/344 [==============================] - 42s 123ms/step - loss: 0.0757 - output_1_loss: 0.0098 - output_2_loss: 0.0659 - output_1_r_square: 0.7189 - output_2_accuracy: 0.9751 - val_loss: 0.0600 - val_output_1_loss: 0.0081 - val_output_2_loss: 0.0519 - val_output_1_r_square: 0.6606 - val_output_2_accuracy: 0.9804
# Epoch 54/80
# 344/344 [==============================] - 42s 122ms/step - loss: 0.0751 - output_1_loss: 0.0105 - output_2_loss: 0.0647 - output_1_r_square: 0.7077 - output_2_accuracy: 0.9757 - val_loss: 0.0725 - val_output_1_loss: 0.0081 - val_output_2_loss: 0.0644 - val_output_1_r_square: 0.6585 - val_output_2_accuracy: 0.9757
# Epoch 55/80
# 344/344 [==============================] - 42s 122ms/step - loss: 0.0722 - output_1_loss: 0.0100 - output_2_loss: 0.0623 - output_1_r_square: 0.7173 - output_2_accuracy: 0.9766 - val_loss: 0.0627 - val_output_1_loss: 0.0081 - val_output_2_loss: 0.0546 - val_output_1_r_square: 0.6597 - val_output_2_accuracy: 0.9786
# Epoch 56/80
# 344/344 [==============================] - 42s 122ms/step - loss: 0.0702 - output_1_loss: 0.0101 - output_2_loss: 0.0601 - output_1_r_square: 0.7169 - output_2_accuracy: 0.9759 - val_loss: 0.0650 - val_output_1_loss: 0.0081 - val_output_2_loss: 0.0569 - val_output_1_r_square: 0.6607 - val_output_2_accuracy: 0.9764
# Epoch 57/80
# 344/344 [==============================] - 42s 122ms/step - loss: 0.0642 - output_1_loss: 0.0099 - output_2_loss: 0.0543 - output_1_r_square: 0.7197 - output_2_accuracy: 0.9797 - val_loss: 0.0592 - val_output_1_loss: 0.0086 - val_output_2_loss: 0.0506 - val_output_1_r_square: 0.6397 - val_output_2_accuracy: 0.9789
# Epoch 58/80
# 344/344 [==============================] - 42s 122ms/step - loss: 0.0672 - output_1_loss: 0.0100 - output_2_loss: 0.0572 - output_1_r_square: 0.7167 - output_2_accuracy: 0.9784 - val_loss: 0.0580 - val_output_1_loss: 0.0082 - val_output_2_loss: 0.0498 - val_output_1_r_square: 0.6532 - val_output_2_accuracy: 0.9836
# Epoch 59/80
# 344/344 [==============================] - 42s 123ms/step - loss: 0.0690 - output_1_loss: 0.0097 - output_2_loss: 0.0593 - output_1_r_square: 0.7241 - output_2_accuracy: 0.9769 - val_loss: 0.0588 - val_output_1_loss: 0.0082 - val_output_2_loss: 0.0507 - val_output_1_r_square: 0.6579 - val_output_2_accuracy: 0.9789
# Epoch 60/80
# 344/344 [==============================] - 42s 123ms/step - loss: 0.0677 - output_1_loss: 0.0099 - output_2_loss: 0.0578 - output_1_r_square: 0.7207 - output_2_accuracy: 0.9788 - val_loss: 0.0699 - val_output_1_loss: 0.0081 - val_output_2_loss: 0.0617 - val_output_1_r_square: 0.6588 - val_output_2_accuracy: 0.9778
# Epoch 61/80
# 344/344 [==============================] - 42s 123ms/step - loss: 0.0654 - output_1_loss: 0.0100 - output_2_loss: 0.0554 - output_1_r_square: 0.7169 - output_2_accuracy: 0.9795 - val_loss: 0.0578 - val_output_1_loss: 0.0081 - val_output_2_loss: 0.0497 - val_output_1_r_square: 0.6601 - val_output_2_accuracy: 0.9811
# Epoch 62/80
# 344/344 [==============================] - 42s 122ms/step - loss: 0.0698 - output_1_loss: 0.0099 - output_2_loss: 0.0599 - output_1_r_square: 0.7200 - output_2_accuracy: 0.9775 - val_loss: 0.0604 - val_output_1_loss: 0.0083 - val_output_2_loss: 0.0521 - val_output_1_r_square: 0.6516 - val_output_2_accuracy: 0.9793
# Epoch 63/80
# 344/344 [==============================] - 42s 123ms/step - loss: 0.0663 - output_1_loss: 0.0098 - output_2_loss: 0.0565 - output_1_r_square: 0.7233 - output_2_accuracy: 0.9802 - val_loss: 0.0666 - val_output_1_loss: 0.0090 - val_output_2_loss: 0.0576 - val_output_1_r_square: 0.6215 - val_output_2_accuracy: 0.9789
# Epoch 64/80
# 344/344 [==============================] - 42s 123ms/step - loss: 0.0649 - output_1_loss: 0.0099 - output_2_loss: 0.0550 - output_1_r_square: 0.7204 - output_2_accuracy: 0.9800 - val_loss: 0.0568 - val_output_1_loss: 0.0081 - val_output_2_loss: 0.0487 - val_output_1_r_square: 0.6578 - val_output_2_accuracy: 0.9818
# Epoch 65/80
# 344/344 [==============================] - 43s 125ms/step - loss: 0.0649 - output_1_loss: 0.0094 - output_2_loss: 0.0555 - output_1_r_square: 0.7338 - output_2_accuracy: 0.9795 - val_loss: 0.0606 - val_output_1_loss: 0.0083 - val_output_2_loss: 0.0523 - val_output_1_r_square: 0.6496 - val_output_2_accuracy: 0.9811
# Epoch 66/80
# 344/344 [==============================] - 43s 126ms/step - loss: 0.0638 - output_1_loss: 0.0098 - output_2_loss: 0.0540 - output_1_r_square: 0.7249 - output_2_accuracy: 0.9807 - val_loss: 0.0529 - val_output_1_loss: 0.0077 - val_output_2_loss: 0.0451 - val_output_1_r_square: 0.6752 - val_output_2_accuracy: 0.9862
# Epoch 67/80
# 344/344 [==============================] - 43s 125ms/step - loss: 0.0609 - output_1_loss: 0.0099 - output_2_loss: 0.0509 - output_1_r_square: 0.7213 - output_2_accuracy: 0.9801 - val_loss: 0.0556 - val_output_1_loss: 0.0080 - val_output_2_loss: 0.0475 - val_output_1_r_square: 0.6626 - val_output_2_accuracy: 0.9836
# Epoch 68/80
# 344/344 [==============================] - 44s 129ms/step - loss: 0.0652 - output_1_loss: 0.0099 - output_2_loss: 0.0553 - output_1_r_square: 0.7227 - output_2_accuracy: 0.9796 - val_loss: 0.0505 - val_output_1_loss: 0.0088 - val_output_2_loss: 0.0417 - val_output_1_r_square: 0.6293 - val_output_2_accuracy: 0.9840
# Epoch 69/80
# 344/344 [==============================] - 44s 129ms/step - loss: 0.0623 - output_1_loss: 0.0097 - output_2_loss: 0.0526 - output_1_r_square: 0.7222 - output_2_accuracy: 0.9803 - val_loss: 0.0555 - val_output_1_loss: 0.0080 - val_output_2_loss: 0.0475 - val_output_1_r_square: 0.6651 - val_output_2_accuracy: 0.9840
# Epoch 70/80
# 344/344 [==============================] - 45s 130ms/step - loss: 0.0644 - output_1_loss: 0.0097 - output_2_loss: 0.0547 - output_1_r_square: 0.7283 - output_2_accuracy: 0.9809 - val_loss: 0.0522 - val_output_1_loss: 0.0077 - val_output_2_loss: 0.0445 - val_output_1_r_square: 0.6746 - val_output_2_accuracy: 0.9847
# Epoch 71/80
# 344/344 [==============================] - 43s 125ms/step - loss: 0.0597 - output_1_loss: 0.0094 - output_2_loss: 0.0503 - output_1_r_square: 0.7341 - output_2_accuracy: 0.9820 - val_loss: 0.0540 - val_output_1_loss: 0.0078 - val_output_2_loss: 0.0462 - val_output_1_r_square: 0.6736 - val_output_2_accuracy: 0.9833
# Epoch 72/80
# 344/344 [==============================] - 43s 124ms/step - loss: 0.0570 - output_1_loss: 0.0096 - output_2_loss: 0.0475 - output_1_r_square: 0.7303 - output_2_accuracy: 0.9826 - val_loss: 0.0510 - val_output_1_loss: 0.0087 - val_output_2_loss: 0.0423 - val_output_1_r_square: 0.6347 - val_output_2_accuracy: 0.9851
# Epoch 73/80
# 344/344 [==============================] - 44s 129ms/step - loss: 0.0635 - output_1_loss: 0.0094 - output_2_loss: 0.0541 - output_1_r_square: 0.7340 - output_2_accuracy: 0.9796 - val_loss: 0.0582 - val_output_1_loss: 0.0079 - val_output_2_loss: 0.0503 - val_output_1_r_square: 0.6692 - val_output_2_accuracy: 0.9800
# Epoch 74/80
# 344/344 [==============================] - 44s 129ms/step - loss: 0.0593 - output_1_loss: 0.0097 - output_2_loss: 0.0496 - output_1_r_square: 0.7273 - output_2_accuracy: 0.9814 - val_loss: 0.0513 - val_output_1_loss: 0.0077 - val_output_2_loss: 0.0436 - val_output_1_r_square: 0.6752 - val_output_2_accuracy: 0.9858
# Epoch 75/80
# 344/344 [==============================] - 44s 128ms/step - loss: 0.0595 - output_1_loss: 0.0097 - output_2_loss: 0.0499 - output_1_r_square: 0.7299 - output_2_accuracy: 0.9820 - val_loss: 0.0526 - val_output_1_loss: 0.0079 - val_output_2_loss: 0.0447 - val_output_1_r_square: 0.6660 - val_output_2_accuracy: 0.9855
# Epoch 76/80
# 344/344 [==============================] - 42s 123ms/step - loss: 0.0595 - output_1_loss: 0.0096 - output_2_loss: 0.0499 - output_1_r_square: 0.7276 - output_2_accuracy: 0.9818 - val_loss: 0.0602 - val_output_1_loss: 0.0082 - val_output_2_loss: 0.0520 - val_output_1_r_square: 0.6551 - val_output_2_accuracy: 0.9829
# Epoch 77/80
# 344/344 [==============================] - 43s 124ms/step - loss: 0.0556 - output_1_loss: 0.0098 - output_2_loss: 0.0458 - output_1_r_square: 0.7246 - output_2_accuracy: 0.9846 - val_loss: 0.0536 - val_output_1_loss: 0.0079 - val_output_2_loss: 0.0457 - val_output_1_r_square: 0.6694 - val_output_2_accuracy: 0.9829
# Epoch 78/80
# 344/344 [==============================] - 42s 123ms/step - loss: 0.0535 - output_1_loss: 0.0097 - output_2_loss: 0.0438 - output_1_r_square: 0.7230 - output_2_accuracy: 0.9829 - val_loss: 0.0575 - val_output_1_loss: 0.0084 - val_output_2_loss: 0.0491 - val_output_1_r_square: 0.6466 - val_output_2_accuracy: 0.9793
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model/Nvidia_CNN\assets
# INFO:tensorflow:Assets written to: model/Nvidia_CNN\assets

# %%
history_path = os.path.join('history.pickle')
with open(history_path, 'rb') as f:
    history = pickle.load(f)

def plots(history):
    # summarize history for accuracy
    fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(2, 2, sharex=True, figsize=(10,6))
    
    ax1.set_title('Angle R Squared')
    ax1.plot(history['output_1_r_square'])
    ax1.plot(history['val_output_1_r_square'])
    ax1.set_yscale('log')
    ax1.legend(['train', 'test'], loc='lower right')
    
    ax2.set_title('Speed Accuracy')
    ax2.plot(history['output_2_accuracy'])
    ax2.plot(history['val_output_2_accuracy'])
    ax2.set_yscale('log')
    ax2.legend(['train', 'test'], loc='lower right')
    
    # summarize history for loss
    ax3.set_title('Angle MSE loss')  
    ax3.plot(history['output_1_loss'])
    ax3.plot(history['val_output_1_loss'])
    ax3.set_yscale('log')
    ax3.legend(['train', 'test'], loc='upper right')
   
    ax4.set_title('Speed loss')
    ax4.plot(history['output_2_loss'])
    ax4.plot(history['val_output_2_loss'])
    ax4.set_yscale('log')
    ax4.legend(['train', 'test'], loc='upper right')
    plt.show()
    
    
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
plots(history)

# %%
images_dir = '../datasets/PiCar/test'
file_list = os.listdir(images_dir)
image_paths = []
pattern = "*.png"

for filename in file_list:
    if fnmatch.fnmatch(filename, pattern):
        image_paths.append(os.path.join(images_dir,filename))

image_paths = natsorted(image_paths)

images = pd.DataFrame (image_paths, columns = ['images'])
images.describe()
# Out:
#                               images
# count                           1020
# unique                          1020
# top     ../datasets/PiCar/test\1.png
# freq                               1

# %%
def test_generator(df, batch_size, target_size):
    while True:

        for i in range(0, len(df), batch_size):
            batch = df
            # Load images and labels
            images = []
            for _, row in batch.iterrows():
                img = cv2.imread(row['images'])
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, target_size)
                images.append(img)

            images = np.array(images) / 255.0

            yield images

# %%
from keras.models import load_model
model = load_model('model/Nvidia_CNN')
testgen = next(test_generator(images, batch_size=1020, target_size=(240, 120)))
predict = model.predict(testgen)
print(predict)
# Out:
# 32/32 [==============================] - 5s 8ms/step
# (array([[0.57233447],
#        [0.7269628 ],
#        [0.24392101],
#        ...,
#        [0.4193011 ],
#        [0.48417288],
#        [0.2161816 ]], dtype=float32), array([[0.00648858],
#        [1.        ],
#        [0.9712993 ],
#        ...,
#        [0.9992417 ],
#        [0.80309635],
#        [0.9901134 ]], dtype=float32))

# %%
angles = pd.DataFrame(predict[0], columns=['Angle'])
speed = pd.DataFrame(predict[1], columns=['speed'])
pred_df = pd.concat([angles, speed],axis=1)
pred_df.insert(0,"image_id", np.arange(1,len(pred_df)+1))

pred_df.head()
# Out:
#    image_id     Angle     speed
# 0         1  0.572334  0.006489
# 1         2  0.726963  1.000000
# 2         3  0.243921  0.971299
# 3         4  0.231288  0.998323
# 4         5  0.231272  0.947584

# %%
pred_df = pred_df.round({'Angle': 4, 'speed': 0})
pred_df.head()
# Out:
#    image_id   Angle  speed
# 0         1  0.5723    0.0
# 1         2  0.7270    1.0
# 2         3  0.2439    1.0
# 3         4  0.2313    1.0
# 4         5  0.2313    1.0

# %%
pred_df.to_csv('Tow_mat4.csv', index=False)

# %%
test = next(custom_generator(X_valid, batch_size=10, target_size=(240, 120), is_training=False))

# %%
predict_test = model.predict(test[0])
# Out:
# 1/1 [==============================] - 0s 18ms/step

# %%
print(predict_test[0])
# Out:
# [[0.5511235 ]
#  [0.7568309 ]
#  [0.7777829 ]
#  [0.72114545]
#  [0.4993554 ]
#  [0.54714364]
#  [0.47722927]
#  [0.5665439 ]
#  [0.6199493 ]
#  [0.7158552 ]]

# %%
print(test[1])
# Out:
# {'output_1': array([0.625 , 0.75  , 0.6875, 0.6875, 0.5   , 0.5   , 0.5   , 0.5625,
#        0.625 , 0.6875]), 'output_2': array([1., 1., 0., 0., 1., 1., 1., 0., 1., 0.])}
