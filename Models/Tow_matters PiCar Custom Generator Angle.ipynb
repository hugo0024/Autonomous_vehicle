# %% [markdown]
# # Tow_matters PiCar

# %%
import os
import fnmatch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from natsort import natsorted

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten,Dropout, BatchNormalization, Conv2D
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras import regularizers
from tensorflow_addons.metrics import RSquare
from imgaug import augmenters as img_aug

import warnings
import random
import cv2
import pickle
import requests
import time

from pushover import Client

warnings.filterwarnings('ignore')

# %%
# Code to send notification to my phone

class PushoverCallback(tf.keras.callbacks.Callback):
    def __init__(self, client, title, sound, interval):
        super(PushoverCallback, self).__init__()
        self.client = client
        self.title = title
        self.sound = sound
        self.interval = interval

    def on_epoch_end(self, epoch, logs=None):
        if epoch % self.interval == 0:
            message = f"Epoch {epoch + 1}: val_loss={logs['val_loss']:.4f}"
            self.client.send_message(message, title=self.title, sound=self.sound)

class TimeoutMonitor(tf.keras.callbacks.Callback):
    def __init__(self, client, title, sound, timeout=300):
        super(TimeoutMonitor, self).__init__()
        self.client = client
        self.title = title
        self.sound = sound
        self.timeout = timeout
        self.start_time = None

    def on_train_begin(self, logs=None):
        self.start_time = time.time()

    def on_epoch_end(self, epoch, logs=None):
        self.start_time = time.time()

    def on_train_end(self, logs=None):
        pass

    def on_epoch_begin(self, epoch, logs=None):
        if self.start_time is not None and (time.time() - self.start_time) > self.timeout:
            message = f"Training has not moved to the next epoch after {self.timeout} seconds"
            self.client.send_message(message, title=self.title, sound=self.sound)
            self.start_time = time.time()

pushover_api_token = 'a3vns7mdqta4mbp42eeqb1ymo6ear5'
pushover_user_key = 'u5c3e3f58nrkui6dpuk5njcpfigxie'
client = Client(pushover_user_key, api_token=pushover_api_token)

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4096)]) # Notice here
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# Load csv file 
df = pd.read_csv('../datasets/PiCar/training_norm.csv', index_col=False)
df.head()
# Out:
#    image_id   angle  speed
# 0         1  0.4375    0.0
# 1         2  0.8125    1.0
# 2         3  0.4375    1.0
# 3         4  0.6250    1.0
# 4         5  0.5000    0.0

# %%
df.shape
# Out:
# (13793, 3)

# %%
#df = df.drop('image_id', axis=1)
#df.head()

# %%
df['angle'].value_counts()
# Out:
# 0.7500    2123
# 0.5000    2046
# 0.6875    2007
# 0.6250    1963
# 0.5625    1609
# 0.4375    1467
# 0.8125    1147
# 0.3750     428
# 0.8750     301
# 0.3125     213
# 0.2500     104
# 0.1250      99
# 0.1875      98
# 0.9375      65
# 0.0000      60
# 1.0000      35
# 0.0625      28
# Name: angle, dtype: int64

# %%
a = df['image_id'].tolist()
b = [x for x in range(a[0], a[-1] + 1)]
missing_vals = list(set(a) ^ set(b))
print('Missing data:', missing_vals)
# Out:
# Missing data: [3141, 3999, 4895, 8285, 10171]

# %%
images_dir = '../datasets/PiCar/train/training_data'
file_list = os.listdir(images_dir)
image_paths = []
pattern = "*.png"

for filename in file_list:
    if fnmatch.fnmatch(filename, pattern):
        image_paths.append(os.path.join(images_dir,filename))

image_paths = natsorted(image_paths)
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/3141.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/3999.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/4895.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/8285.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/10171.png']

image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\3141.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\3999.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\4895.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\8285.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\10171.png']

images = pd.DataFrame (image_paths, columns = ['images'])
images.describe()
# Out:
#                                              images
# count                                         13793
# unique                                        13793
# top     ../datasets/PiCar/train/training_data\1.png
# freq                                              1

# %%
df_all = pd.concat([df, images], axis=1)
df_all = df_all.drop('image_id', axis=1)
df_all = df_all.drop('speed', axis=1)
df_all.tail()
# Out:
#         angle                                           images
# 13788  0.6250  ../datasets/PiCar/train/training_data\13794.png
# 13789  0.4375  ../datasets/PiCar/train/training_data\13795.png
# 13790  0.5625  ../datasets/PiCar/train/training_data\13796.png
# 13791  0.6250  ../datasets/PiCar/train/training_data\13797.png
# 13792  0.6875  ../datasets/PiCar/train/training_data\13798.png

# %%
df_all.shape
# Out:
# (13793, 2)

# %%
#le = LabelEncoder()
#df_all['angle']= le.fit_transform(df_all['angle'])
#df_all.head()

# %%
image_paths = df_all['images'].tolist()
steering_angles = df_all['angle'].tolist()

image_index = 10
plt.imshow(Image.open(image_paths[image_index]))
print("image_path: %s" % image_paths[image_index]) 
print("steering_Angle:", steering_angles[image_index])
# Out:
# image_path: ../datasets/PiCar/train/training_data\11.png
# steering_Angle: 0.6875

# %%
test_image = cv2.imread(df_all['images'][6])
test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)
print(test_image.shape)
test_image = cv2.resize(test_image, (240,240))
plt.imshow(test_image)
plt.show()
# Out:
# (240, 320, 3)

# %%
X_train, X_valid = train_test_split( df_all, test_size=0.2)
print("Training data: %d\nValidation data: %d" % (len(X_train), len(X_valid)))
# Out:
# Training data: 11034
# Validation data: 2759

# %%
from tensorflow.keras.applications import VGG16

class Nvidia_CNN(tf.keras.Model):
  def __init__(self):
    super().__init__()

    self.vgg = VGG16(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
    self.conv4 = Conv2D(64, 3, strides=(2, 2), activation='relu')

    self.flatten = Flatten()
    self.d1 = Dense(100, activation='relu')
    self.d2 = Dense(50, activation='relu')
    self.d3 = Dense(10, activation='relu')
    self.d4 = Dense(5, activation='relu')

    self.Y1 = Dense(1, activation='relu')

  def call(self, x):
    x = self.vgg(x)
    x = self.conv4(x)

    x = self.flatten(x)
    x = self.d1(x)
    x = self.d2(x)
    x = self.d3(x)
    x = self.d4(x)

    y1 = self.Y1(x)


    return y1

# %%
def zoom(image):
    zoom = img_aug.Affine(scale=(1, 1.2))  # zoom from 100% (no zoom) to 120%
    image = zoom.augment_image(image)
    return image

def pan(image):
    # pan left / right / up / down about 10%
    pan = img_aug.Affine(translate_percent= {"x" : (-0.1, 0.1), "y": (-0.1, 0.1)})
    image = pan.augment_image(image)
    return image

def adjust_brightness(image):
    # increase or decrease brightness by 30%
    brightness = img_aug.Multiply((0.7, 1.3))
    image = brightness.augment_image(image)
    return image

def blur(image):
    kernel_size = random.randint(1, 3)  # kernel larger than 5 would make the image way too blurry
    image = cv2.blur(image,(kernel_size, kernel_size))
    return image

def random_augment(image):
    if np.random.rand() < 0.5:
        image = pan(image)
    if np.random.rand() < 0.5:
        image = zoom(image)
    if np.random.rand() < 0.5:
        image = blur(image)
    if np.random.rand() < 0.5:
        image = adjust_brightness(image)
    return image

# %%
def random_flip(image):
    is_flip = random.randint(0, 1)
    if is_flip == 1:
        image = cv2.flip(image,1)
    return image, is_flip

# %%
def custom_generator(df, batch_size, target_size, is_training):
    while True:
        # Shuffle the data
        df = df.sample(frac=1).reset_index(drop=True)
        for i in range(0, len(df), batch_size):
            batch = df[i:i+batch_size]
            # Load images and labels
            images = []
            angles = []
            for _, row in batch.iterrows():
                img = cv2.imread(row['images'])
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, target_size)
                angle = row['angle']

                if is_training:
                    img = random_augment(img)
                    img, is_flip = random_flip(img)
                    if is_flip:
                        angle = 1 - angle

                images.append(img)
                angles.append(angle)

            # Normalize images
            images = np.array(images) / 255.0
            # Convert labels to arrays
            angles = np.array(angles)
            yield images, angles

# %%
tf.keras.backend.clear_session()

# Early stop added
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
pushover_callback = PushoverCallback(client=client, title='Model Training Update', sound='cashregister', interval=3)
timeout_callback = TimeoutMonitor(client=client, title='Training Stuck!!!!!!!!', sound='falling')

train_gen = custom_generator(X_train, batch_size=32 ,target_size=(224,224), is_training= True)
val_gen = custom_generator(X_valid, batch_size=32, target_size=(224,224), is_training= False)

model = Nvidia_CNN()

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                    loss = tf.keras.losses.MeanSquaredError(),
                    metrics = RSquare())


history = model.fit(train_gen,
                    steps_per_epoch=len(X_train) // 32,
                    validation_data=val_gen,
                    validation_steps=len(X_valid) // 32,
                    callbacks=[callback, pushover_callback, timeout_callback],
                    epochs=60)

model.save('model/Nvidia_CNN_angle',save_format='tf')

history_path = os.path.join('history_angle.pickle')
with open(history_path, 'wb') as f:
    pickle.dump(history.history, f, pickle.HIGHEST_PROTOCOL)
# Out:
# Epoch 1/60
# 344/344 [==============================] - 174s 453ms/step - loss: 0.0105 - r_square: 0.7030 - val_loss: 0.0074 - val_r_square: 0.6941
# Epoch 2/60
# 344/344 [==============================] - 210s 551ms/step - loss: 0.0081 - r_square: 0.7698 - val_loss: 0.0067 - val_r_square: 0.7205
# Epoch 3/60
# 344/344 [==============================] - 186s 542ms/step - loss: 0.0078 - r_square: 0.7816 - val_loss: 0.0070 - val_r_square: 0.7088
# Epoch 4/60
# 344/344 [==============================] - 180s 524ms/step - loss: 0.0075 - r_square: 0.7897 - val_loss: 0.0062 - val_r_square: 0.7436
# Epoch 5/60
# 344/344 [==============================] - 175s 510ms/step - loss: 0.0070 - r_square: 0.8022 - val_loss: 0.0067 - val_r_square: 0.7225
# Epoch 6/60
# 344/344 [==============================] - 177s 515ms/step - loss: 0.0068 - r_square: 0.8075 - val_loss: 0.0069 - val_r_square: 0.7132
# Epoch 7/60
# 344/344 [==============================] - 177s 515ms/step - loss: 0.0064 - r_square: 0.8179 - val_loss: 0.0058 - val_r_square: 0.7580
# Epoch 8/60
# 344/344 [==============================] - 177s 514ms/step - loss: 0.0060 - r_square: 0.8302 - val_loss: 0.0051 - val_r_square: 0.7874
# Epoch 9/60
# 344/344 [==============================] - 170s 494ms/step - loss: 0.0061 - r_square: 0.8297 - val_loss: 0.0064 - val_r_square: 0.7359
# Epoch 10/60
# 344/344 [==============================] - 155s 451ms/step - loss: 0.0058 - r_square: 0.8368 - val_loss: 0.0052 - val_r_square: 0.7829
# Epoch 11/60
# 344/344 [==============================] - 159s 463ms/step - loss: 0.0058 - r_square: 0.8351 - val_loss: 0.0055 - val_r_square: 0.7713
# Epoch 12/60
# 344/344 [==============================] - 159s 462ms/step - loss: 0.0055 - r_square: 0.8461 - val_loss: 0.0058 - val_r_square: 0.7602
# Epoch 13/60
# 344/344 [==============================] - 159s 462ms/step - loss: 0.0056 - r_square: 0.8424 - val_loss: 0.0051 - val_r_square: 0.7901
# Epoch 14/60
# 344/344 [==============================] - 158s 460ms/step - loss: 0.0053 - r_square: 0.8489 - val_loss: 0.0050 - val_r_square: 0.7932
# Epoch 15/60
# 344/344 [==============================] - 161s 469ms/step - loss: 0.0053 - r_square: 0.8508 - val_loss: 0.0052 - val_r_square: 0.7856
# Epoch 16/60
# 344/344 [==============================] - 180s 525ms/step - loss: 0.0053 - r_square: 0.8508 - val_loss: 0.0053 - val_r_square: 0.7794
# Epoch 17/60
# 344/344 [==============================] - 180s 523ms/step - loss: 0.0053 - r_square: 0.8502 - val_loss: 0.0050 - val_r_square: 0.7919
# Epoch 18/60
# 344/344 [==============================] - 179s 519ms/step - loss: 0.0051 - r_square: 0.8545 - val_loss: 0.0049 - val_r_square: 0.7970
# Epoch 19/60
# 344/344 [==============================] - 172s 501ms/step - loss: 0.0052 - r_square: 0.8545 - val_loss: 0.0048 - val_r_square: 0.8029
# Epoch 20/60
# 344/344 [==============================] - 156s 452ms/step - loss: 0.0049 - r_square: 0.8625 - val_loss: 0.0049 - val_r_square: 0.7966
# Epoch 21/60
# 344/344 [==============================] - 158s 459ms/step - loss: 0.0050 - r_square: 0.8575 - val_loss: 0.0049 - val_r_square: 0.7978
# Epoch 22/60
# 344/344 [==============================] - 165s 481ms/step - loss: 0.0049 - r_square: 0.8609 - val_loss: 0.0048 - val_r_square: 0.8028
# Epoch 23/60
# 344/344 [==============================] - 184s 534ms/step - loss: 0.0047 - r_square: 0.8668 - val_loss: 0.0054 - val_r_square: 0.7745
# Epoch 24/60
# 344/344 [==============================] - 184s 535ms/step - loss: 0.0048 - r_square: 0.8648 - val_loss: 0.0047 - val_r_square: 0.8064
# Epoch 25/60
# 344/344 [==============================] - 183s 531ms/step - loss: 0.0048 - r_square: 0.8643 - val_loss: 0.0050 - val_r_square: 0.7914
# Epoch 26/60
# 344/344 [==============================] - 190s 553ms/step - loss: 0.0045 - r_square: 0.8734 - val_loss: 0.0050 - val_r_square: 0.7917
# Epoch 27/60
# 344/344 [==============================] - 181s 525ms/step - loss: 0.0046 - r_square: 0.8721 - val_loss: 0.0054 - val_r_square: 0.7753
# Epoch 28/60
# 344/344 [==============================] - 129s 376ms/step - loss: 0.0047 - r_square: 0.8674 - val_loss: 0.0055 - val_r_square: 0.7724
# Epoch 29/60
# 344/344 [==============================] - 170s 494ms/step - loss: 0.0044 - r_square: 0.8751 - val_loss: 0.0047 - val_r_square: 0.8038
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 14). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model/Nvidia_CNN_angle\assets
# INFO:tensorflow:Assets written to: model/Nvidia_CNN_angle\assets

# %%
history_path = os.path.join('history_angle.pickle')
with open(history_path, 'rb') as f:
    history = pickle.load(f)

def plots(history):
    # summarize history for accuracy
    fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(2, 2, figsize=(10,6))
    
    ax1.set_title('Angle R Squared')
    ax1.plot(history['r_square'])
    ax1.plot(history['r_square'])
    ax1.set_yscale('log')
    ax1.legend(['train', 'test'], loc='lower right')

    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
plots(history)

# %%
images_dir = '../datasets/PiCar/test'
file_list = os.listdir(images_dir)
image_paths = []
pattern = "*.png"

for filename in file_list:
    if fnmatch.fnmatch(filename, pattern):
        image_paths.append(os.path.join(images_dir,filename))

image_paths = natsorted(image_paths)

images = pd.DataFrame (image_paths, columns = ['images'])
images.describe()
# Out:
#                               images
# count                           1020
# unique                          1020
# top     ../datasets/PiCar/test\1.png
# freq                               1

# %%
def test_generator(df, batch_size, target_size):
    while True:

        for i in range(0, len(df), batch_size):
            batch = df
            # Load images and labels
            images = []
            for _, row in batch.iterrows():
                img = cv2.imread(row['images'])
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, target_size)
                images.append(img)

            images = np.array(images) / 255.0

            yield images

# %%
from keras.models import load_model
model = load_model('model/Nvidia_CNN_angle')
testgen = next(test_generator(images, batch_size=1020, target_size=(224, 224)))
predict = model.predict(testgen)
print(predict)
# Out:
# 32/32 [==============================] - 8s 237ms/step
# [[0.5797155 ]
#  [0.75810784]
#  [0.22428438]
#  ...
#  [0.35355094]
#  [0.06531069]
#  [0.3076341 ]]

# %%
angles = pd.DataFrame(predict, columns=['Angle'])
print(angles)
pred_df = pd.concat([angles],axis=1)
pred_df.insert(0,"image_id", np.arange(1,len(pred_df)+1))
print(pred_df.head())
# Out:
#          Angle
# 0     0.579715
# 1     0.758108
# 2     0.224284
# 3     0.106377
# 4     0.121487
# ...        ...
# 1015  0.510521
# 1016  0.643399
# 1017  0.353551
# 1018  0.065311
# 1019  0.307634
#
# [1020 rows x 1 columns]
#    image_id     Angle
# 0         1  0.579715
# 1         2  0.758108
# 2         3  0.224284
# 3         4  0.106377
# 4         5  0.121487

# %%
pred_df = pred_df.round({'Angle': 4})
pred_df.head()
# Out:
#    image_id   Angle
# 0         1  0.5797
# 1         2  0.7581
# 2         3  0.2243
# 3         4  0.1064
# 4         5  0.1215

# %%
pred_df.to_csv('Tow_mat4.csv', index=False)

# %%
test = next(custom_generator(X_valid, batch_size=10, target_size=(240, 240), is_training=False))

# %%
predict_test = model.predict(test[0])
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
print(predict_test)
# Out:
# [[0.58363444]
#  [0.6319189 ]
#  [0.52877957]
#  [0.56911427]
#  [0.5409034 ]
#  [0.45694974]
#  [0.53909516]
#  [0.5725044 ]
#  [0.76017755]
#  [0.5856666 ]]

# %%
print(test[1])
# Out:
# [0.625  0.625  0.5    0.6875 0.5    0.4375 0.5625 0.625  0.875  0.5625]
