# %% [markdown]
# # MobileNet_CNN2
# Pre-trained model

# %%
import os
import fnmatch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from natsort import natsorted

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten,Dropout, BatchNormalization, Conv2D
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras import regularizers
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow_addons.metrics import RSquare
from imgaug import augmenters as img_aug

import warnings
import random
import cv2
import pickle
import requests
import time

#from pushover import Client

warnings.filterwarnings('ignore')
# Out:
# /home/roscopikotrain/programs/anaconda3/lib/python3.8/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.9.0 and strictly below 2.12.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.12.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# Code to send notification to my phone

class PushoverCallback(tf.keras.callbacks.Callback):
    def __init__(self, client, title, sound, interval):
        super(PushoverCallback, self).__init__()
        self.client = client
        self.title = title
        self.sound = sound
        self.interval = interval

    def on_epoch_end(self, epoch, logs=None):
        if epoch % self.interval == 0:
            message = f"Epoch {epoch + 1}: val_loss={logs['val_loss']:.4f}"
            self.client.send_message(message, title=self.title, sound=self.sound)

class TimeoutMonitor(tf.keras.callbacks.Callback):
    def __init__(self, client, title, sound, timeout=300):
        super(TimeoutMonitor, self).__init__()
        self.client = client
        self.title = title
        self.sound = sound
        self.timeout = timeout
        self.start_time = None

    def on_train_begin(self, logs=None):
        self.start_time = time.time()

    def on_epoch_end(self, epoch, logs=None):
        self.start_time = time.time()

    def on_train_end(self, logs=None):
        pass

    def on_epoch_begin(self, epoch, logs=None):
        if self.start_time is not None and (time.time() - self.start_time) > self.timeout:
            message = f"Training has not moved to the next epoch after {self.timeout} seconds"
            self.client.send_message(message, title=self.title, sound=self.sound)
            self.start_time = time.time()

pushover_api_token = 'a3vns7mdqta4mbp42eeqb1ymo6ear5'
pushover_user_key = 'u5c3e3f58nrkui6dpuk5njcpfigxie'
client = Client(pushover_user_key, api_token=pushover_api_token)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-319442d81d55> in <module>
#      40 pushover_api_token = 'a3vns7mdqta4mbp42eeqb1ymo6ear5'
#      41 pushover_user_key = 'u5c3e3f58nrkui6dpuk5njcpfigxie'
# ---> 42 client = Client(pushover_user_key, api_token=pushover_api_token)
#
# NameError: name 'Client' is not defined

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    #tf.config.experimental.set_virtual_device_configuration(
        #gpus[0],
        #[tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4096)]) # Notice here
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)

# %%
# Load csv file 
df = pd.read_csv('../datasets/PiCar/training_norm.csv', index_col=False)
df.head()
# Out:
#    image_id   angle  speed
# 0         1  0.4375    0.0
# 1         2  0.8125    1.0
# 2         3  0.4375    1.0
# 3         4  0.6250    1.0
# 4         5  0.5000    0.0

# %%
df.shape
# Out:
# (13793, 3)

# %%
#df = df.drop('image_id', axis=1)
#df.head()

# %%
df['angle'].value_counts()
# Out:
# 0.7500    2123
# 0.5000    2046
# 0.6875    2007
# 0.6250    1963
# 0.5625    1609
# 0.4375    1467
# 0.8125    1147
# 0.3750     428
# 0.8750     301
# 0.3125     213
# 0.2500     104
# 0.1250      99
# 0.1875      98
# 0.9375      65
# 0.0000      60
# 1.0000      35
# 0.0625      28
# Name: angle, dtype: int64

# %%
a = df['image_id'].tolist()
b = [x for x in range(a[0], a[-1] + 1)]
missing_vals = list(set(a) ^ set(b))
print('Missing data:', missing_vals)
# Out:
# Missing data: [3141, 3999, 4895, 8285, 10171]

# %%
images_dir = '../datasets/PiCar/train/training_data'
file_list = os.listdir(images_dir)
image_paths = []
pattern = "*.png"

for filename in file_list:
    if fnmatch.fnmatch(filename, pattern):
        image_paths.append(os.path.join(images_dir,filename))

image_paths = natsorted(image_paths)
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/3141.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/3999.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/4895.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/8285.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data/10171.png']

image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\3141.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\3999.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\4895.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\8285.png']
image_paths = [string for string in image_paths if string != '../datasets/PiCar/train/training_data\\10171.png']

images = pd.DataFrame (image_paths, columns = ['images'])
images.describe()
# Out:
#                                                  images
# count                                             13793
# unique                                            13793
# top     ../datasets/PiCar/train/training_data/11898.png
# freq                                                  1

# %%
df_all = pd.concat([df, images], axis=1)
df_all = df_all.drop('image_id', axis=1)
df_all.tail()
# Out:
#         angle  speed                                           images
# 13788  0.6250    1.0  ../datasets/PiCar/train/training_data/13794.png
# 13789  0.4375    1.0  ../datasets/PiCar/train/training_data/13795.png
# 13790  0.5625    0.0  ../datasets/PiCar/train/training_data/13796.png
# 13791  0.6250    0.0  ../datasets/PiCar/train/training_data/13797.png
# 13792  0.6875    1.0  ../datasets/PiCar/train/training_data/13798.png

# %%
df_all.shape
# Out:
# (13793, 3)

# %%
#le = LabelEncoder()
#df_all['angle']= le.fit_transform(df_all['angle'])
#df_all.head()

# %%
image_paths = df_all['images'].tolist()
steering_angles = df_all['angle'].tolist()
speed = df_all['speed'].tolist()


image_index = 10
plt.imshow(Image.open(image_paths[image_index]))
print("image_path: %s" % image_paths[image_index]) 
print("steering_Angle:", steering_angles[image_index]) 
print("Speed:", speed[image_index])
# Out:
# image_path: ../datasets/PiCar/train/training_data/11.png
# steering_Angle: 0.6875
# Speed: 0.0

# %%
test_image = cv2.imread(df_all['images'][10])
test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)
print(test_image.shape)
test_image = cv2.resize(test_image, (224,224))
plt.imshow(test_image)
plt.show()
# Out:
# (240, 320, 3)

# %%
X_train, X_valid = train_test_split( df_all, test_size=0.2)
print("Training data: %d\nValidation data: %d" % (len(X_train), len(X_valid)))
# Out:
# Training data: 11034
# Validation data: 2759

# %%
from tensorflow.keras.applications import MobileNet

class MobileNet_CNN2(tf.keras.Model):
  def __init__(self):
    super().__init__()

    self.mn = MobileNet(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
    self.batch1 = BatchNormalization()
    self.conv1 = Conv2D(64, 3, activation='relu')# stride removing

    self.flatten = Flatten()
    self.drop1 = Dropout(0.25)
    self.d1 = Dense(128, activation='relu')
    self.d2 = Dense(64, activation='relu')
    self.d3 = Dense(32, activation='relu')
    self.drop2 = Dropout(0.25)
    self.d4 = Dense(16, activation='relu')

    self.Y1 = Dense(1, activation='relu')    
    self.Y2 = Dense(1, activation = 'sigmoid')

  def call(self, x):
    x = self.mn(x)
    x = self.batch1(x)
    x = self.conv1(x)

    x = self.flatten(x)
    x = self.drop1(x)
    x = self.d1(x)
    x = self.d2(x)
    x = self.d3(x)
    x = self.drop2(x)
    x = self.d4(x)

    y1 = self.Y1(x)
    y2 = self.Y2(x)
    
    return y1,y2

# %%
model = MobileNet_CNN2()
model.build((1,224, 224, 3))
model.summary()
# Out:
# Model: "mobile_net_cnn2_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_224 (Functio  (None, 7, 7, 1024)       3228864
#  nal)
#
#  batch_normalization_3 (Batc  multiple                 4096
#  hNormalization)
#
#  conv2d_3 (Conv2D)           multiple                  589888
#
#  flatten_3 (Flatten)         multiple                  0
#
#  dropout_5 (Dropout)         multiple                  0
#
#  dense_18 (Dense)            multiple                  204928
#
#  dense_19 (Dense)            multiple                  8256
#
#  dense_20 (Dense)            multiple                  2080
#
#  dropout_6 (Dropout)         multiple                  0
#
#  dense_21 (Dense)            multiple                  528
#
#  dense_22 (Dense)            multiple                  17
#
#  dense_23 (Dense)            multiple                  17
#
# =================================================================
# Total params: 4,038,674
# Trainable params: 4,014,738
# Non-trainable params: 23,936
# _________________________________________________________________

# %%
def zoom(image):
    zoom = img_aug.Affine(scale=(1, 1.2))  # zoom from 100% (no zoom) to 120%
    image = zoom.augment_image(image)
    return image

def pan(image):
    # pan left / right / up / down about 10%
    pan = img_aug.Affine(translate_percent= {"x" : (-0.1, 0.1), "y": (-0.1, 0.1)})
    image = pan.augment_image(image)
    return image

def adjust_brightness(image):
    # increase or decrease brightness by 30%
    brightness = img_aug.Multiply((0.7, 1.3))
    image = brightness.augment_image(image)
    return image

def blur(image):
    kernel_size = random.randint(1, 3)  # kernel larger than 5 would make the image way too blurry
    image = cv2.blur(image,(kernel_size, kernel_size))
    return image

def random_augment(image):
    if np.random.rand() < 0.5:
        image = pan(image)
    if np.random.rand() < 0.5:
        image = zoom(image)
    if np.random.rand() < 0.5:
        image = blur(image)
    if np.random.rand() < 0.5:
        image = adjust_brightness(image)
    return image

# %%
def random_flip(image):
    is_flip = random.randint(0, 1)
    if is_flip == 1:
        image = cv2.flip(image,1)
    return image, is_flip

# %%
def custom_generator(df, batch_size, target_size, is_training):
    while True:
        # Shuffle the data
        df = df.sample(frac=1).reset_index(drop=True)
        for i in range(0, len(df), batch_size):
            batch = df[i:i+batch_size]
            # Load images and labels
            images = []
            angles = []
            speeds = []
            for _, row in batch.iterrows():
                img = cv2.imread(row['images'])
                angle = row['angle']
                speed = row['speed']

                if is_training:
                    img = random_augment(img)
                    img, is_flip = random_flip(img)
                    if is_flip:
                        angle = 1 - angle

                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, target_size)

                images.append(img)
                angles.append(angle)
                speeds.append(speed)

            # Normalize images
            images = np.array(images) / 255.0
            # Convert labels to arrays
            angles = np.array(angles)
            speeds = np.array(speeds)
            yield images, {'output_1': angles, 'output_2': speeds}

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %%
tf.keras.backend.clear_session()

# Early stop added
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
#pushover_callback = PushoverCallback(client=client, title='Model Training Update', sound='cashregister', interval=1)
#timeout_callback = TimeoutMonitor(client=client, title='Training Stuck!!!!!!!!', sound='falling')

train_gen = custom_generator(X_train, batch_size=32 ,target_size=(224, 224), is_training= True)
val_gen = custom_generator(X_valid, batch_size=32, target_size=(224, 224), is_training= False)

model = MobileNet_CNN()

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                       loss={
        "output_1" : tf.keras.losses.MeanSquaredError(),
        "output_2" : tf.keras.losses.BinaryCrossentropy(from_logits=False)},
        metrics={"output_1": 'mse', "output_2": 'accuracy'})


history = model.fit(train_gen,
                    steps_per_epoch=len(X_train) // 32,
                    validation_data=val_gen,
                    validation_steps=len(X_valid) // 32,
                    callbacks=[callback],
                    epochs=150)

model.save('model/MobileNet_CNN',save_format='tf')

history_path = os.path.join('history.pickle')
with open(history_path, 'wb') as f:
    pickle.dump(history.history, f, pickle.HIGHEST_PROTOCOL)
# Out:
# Epoch 1/150
# 344/344 [==============================] - 555s 2s/step - loss: 0.3626 - output_1_loss: 0.1507 - output_2_loss: 0.2120 - output_1_mse: 0.1507 - output_2_accuracy: 0.9178 - val_loss: 0.1478 - val_output_1_loss: 0.0469 - val_output_2_loss: 0.1009 - val_output_1_mse: 0.0469 - val_output_2_accuracy: 0.9608
# Epoch 2/150
# 344/344 [==============================] - 538s 2s/step - loss: 0.1904 - output_1_loss: 0.1030 - output_2_loss: 0.0874 - output_1_mse: 0.1030 - output_2_accuracy: 0.9755 - val_loss: 0.0678 - val_output_1_loss: 0.0234 - val_output_2_loss: 0.0444 - val_output_1_mse: 0.0234 - val_output_2_accuracy: 0.9847
# Epoch 3/150
# 344/344 [==============================] - 529s 2s/step - loss: 0.1364 - output_1_loss: 0.0707 - output_2_loss: 0.0657 - output_1_mse: 0.0707 - output_2_accuracy: 0.9808 - val_loss: 0.0685 - val_output_1_loss: 0.0194 - val_output_2_loss: 0.0491 - val_output_1_mse: 0.0194 - val_output_2_accuracy: 0.9833
# Epoch 4/150
# 344/344 [==============================] - 525s 2s/step - loss: 0.1113 - output_1_loss: 0.0541 - output_2_loss: 0.0572 - output_1_mse: 0.0541 - output_2_accuracy: 0.9835 - val_loss: 0.0710 - val_output_1_loss: 0.0258 - val_output_2_loss: 0.0452 - val_output_1_mse: 0.0258 - val_output_2_accuracy: 0.9836
# Epoch 5/150
# 344/344 [==============================] - 523s 2s/step - loss: 0.0873 - output_1_loss: 0.0426 - output_2_loss: 0.0446 - output_1_mse: 0.0426 - output_2_accuracy: 0.9877 - val_loss: 0.0651 - val_output_1_loss: 0.0199 - val_output_2_loss: 0.0452 - val_output_1_mse: 0.0199 - val_output_2_accuracy: 0.9866
# Epoch 6/150
# 344/344 [==============================] - 524s 2s/step - loss: 0.0777 - output_1_loss: 0.0358 - output_2_loss: 0.0419 - output_1_mse: 0.0358 - output_2_accuracy: 0.9861 - val_loss: 0.0618 - val_output_1_loss: 0.0181 - val_output_2_loss: 0.0437 - val_output_1_mse: 0.0181 - val_output_2_accuracy: 0.9836
# Epoch 7/150
# 344/344 [==============================] - 522s 2s/step - loss: 0.0719 - output_1_loss: 0.0325 - output_2_loss: 0.0394 - output_1_mse: 0.0325 - output_2_accuracy: 0.9881 - val_loss: 0.0627 - val_output_1_loss: 0.0219 - val_output_2_loss: 0.0408 - val_output_1_mse: 0.0219 - val_output_2_accuracy: 0.9869
# Epoch 8/150
# 344/344 [==============================] - 523s 2s/step - loss: 0.0672 - output_1_loss: 0.0301 - output_2_loss: 0.0371 - output_1_mse: 0.0301 - output_2_accuracy: 0.9888 - val_loss: 0.0737 - val_output_1_loss: 0.0209 - val_output_2_loss: 0.0528 - val_output_1_mse: 0.0209 - val_output_2_accuracy: 0.9826
# Epoch 9/150
# 344/344 [==============================] - 520s 2s/step - loss: 0.0613 - output_1_loss: 0.0273 - output_2_loss: 0.0340 - output_1_mse: 0.0273 - output_2_accuracy: 0.9896 - val_loss: 0.0649 - val_output_1_loss: 0.0248 - val_output_2_loss: 0.0401 - val_output_1_mse: 0.0248 - val_output_2_accuracy: 0.9869
# Epoch 10/150
# 344/344 [==============================] - 518s 2s/step - loss: 0.0535 - output_1_loss: 0.0251 - output_2_loss: 0.0284 - output_1_mse: 0.0251 - output_2_accuracy: 0.9899 - val_loss: 0.0667 - val_output_1_loss: 0.0206 - val_output_2_loss: 0.0461 - val_output_1_mse: 0.0206 - val_output_2_accuracy: 0.9880
# Epoch 11/150
# 344/344 [==============================] - 518s 2s/step - loss: 0.0521 - output_1_loss: 0.0237 - output_2_loss: 0.0284 - output_1_mse: 0.0237 - output_2_accuracy: 0.9907 - val_loss: 0.0654 - val_output_1_loss: 0.0255 - val_output_2_loss: 0.0399 - val_output_1_mse: 0.0255 - val_output_2_accuracy: 0.9851
# Epoch 12/150
# 344/344 [==============================] - 523s 2s/step - loss: 0.0510 - output_1_loss: 0.0221 - output_2_loss: 0.0289 - output_1_mse: 0.0221 - output_2_accuracy: 0.9906 - val_loss: 0.0626 - val_output_1_loss: 0.0167 - val_output_2_loss: 0.0459 - val_output_1_mse: 0.0167 - val_output_2_accuracy: 0.9822
# Epoch 13/150
# 344/344 [==============================] - 520s 2s/step - loss: 0.0484 - output_1_loss: 0.0220 - output_2_loss: 0.0264 - output_1_mse: 0.0220 - output_2_accuracy: 0.9903 - val_loss: 0.0738 - val_output_1_loss: 0.0196 - val_output_2_loss: 0.0542 - val_output_1_mse: 0.0196 - val_output_2_accuracy: 0.9800
# Epoch 14/150
# 344/344 [==============================] - 521s 2s/step - loss: 0.0512 - output_1_loss: 0.0218 - output_2_loss: 0.0294 - output_1_mse: 0.0218 - output_2_accuracy: 0.9905 - val_loss: 0.0651 - val_output_1_loss: 0.0194 - val_output_2_loss: 0.0457 - val_output_1_mse: 0.0194 - val_output_2_accuracy: 0.9873
# Epoch 15/150
# 344/344 [==============================] - 519s 2s/step - loss: 0.0487 - output_1_loss: 0.0210 - output_2_loss: 0.0277 - output_1_mse: 0.0210 - output_2_accuracy: 0.9914 - val_loss: 0.1219 - val_output_1_loss: 0.0212 - val_output_2_loss: 0.1007 - val_output_1_mse: 0.0212 - val_output_2_accuracy: 0.9709
# Epoch 16/150
# 344/344 [==============================] - 516s 2s/step - loss: 0.0405 - output_1_loss: 0.0199 - output_2_loss: 0.0205 - output_1_mse: 0.0199 - output_2_accuracy: 0.9925 - val_loss: 0.0619 - val_output_1_loss: 0.0146 - val_output_2_loss: 0.0473 - val_output_1_mse: 0.0146 - val_output_2_accuracy: 0.9873
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _update_step_xla, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 29). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model/MobileNet_CNN/assets
# INFO:tensorflow:Assets written to: model/MobileNet_CNN/assets

# %%
history_path = os.path.join('history.pickle')
with open(history_path, 'rb') as f:
    history = pickle.load(f)

def plots(history):
    # summarize history for accuracy
    fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(2, 2, sharex=True, figsize=(10,6))
    
    ax1.set_title('Angle Loss')
    ax1.plot(history['output_1_loss'])
    ax1.plot(history['val_output_1_mse'])
    ax1.set_yscale('log')
    ax1.legend(['train', 'test'], loc='lower right')
    
    ax2.set_title('Speed Accuracy')
    ax2.plot(history['output_2_accuracy'])
    ax2.plot(history['val_output_2_accuracy'])
    ax2.set_yscale('log')
    ax2.legend(['train', 'test'], loc='lower right')
    
    # summarize history for loss
    ax3.set_title('Angle MSE loss')  
    ax3.plot(history['output_1_loss'])
    ax3.plot(history['val_output_1_loss'])
    ax3.set_yscale('log')
    ax3.legend(['train', 'test'], loc='upper right')
   
    ax4.set_title('Speed loss')
    ax4.plot(history['output_2_loss'])
    ax4.plot(history['val_output_2_loss'])
    ax4.set_yscale('log')
    ax4.legend(['train', 'test'], loc='upper right')
    plt.show()
    
    
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
plots(history)

# %% [markdown]
# # Evaluation using validation set

# %%
def validation_generator(df, batch_size, target_size):
    while True:

        for i in range(0, len(df), batch_size):
            batch = df
            # Load images and labels
            images = []
            for _, row in batch.iterrows():
                img = cv2.imread(row['images'])
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, target_size)
                images.append(img)

            images = np.array(images) / 255.0

            yield images

# %%
from keras.models import load_model
model = load_model('model/MobileNet_CNN')
valgen = next(validation_generator(X_valid, batch_size=2759, target_size=(224, 224)))
predict = model.predict(valgen)
print(predict)
# Out:
# 87/87 [==============================] - 19s 214ms/step
# (array([[0.60691   ],
#        [0.3820805 ],
#        [0.6380668 ],
#        ...,
#        [0.48228604],
#        [0.62073463],
#        [0.4710983 ]], dtype=float32), array([[0.9999996 ],
#        [0.9999335 ],
#        [1.        ],
#        ...,
#        [0.99998116],
#        [0.99997264],
#        [0.9998344 ]], dtype=float32))

# %%
angles = pd.DataFrame(predict[0], columns=['angle'])
speed = pd.DataFrame(predict[1], columns=['speed'])
pred_df = pd.concat([angles, speed],axis=1)
pred_df.insert(0,"image_id", np.arange(1,len(pred_df)+1))

pred_df.head()
# Out:
#    image_id     angle         speed
# 0         1  0.606910  9.999996e-01
# 1         2  0.382080  9.999335e-01
# 2         3  0.638067  1.000000e+00
# 3         4  0.606343  2.922744e-08
# 4         5  0.423157  3.542524e-04

# %%
pred_df.shape
# Out:
# (2759, 3)

# %% [markdown]
# ### MSE before round

# %%
mse = tf.keras.losses.MeanSquaredError()
angle_mse = mse(X_valid['angle'], pred_df['angle']).numpy()
speed_mse = mse(X_valid['speed'], pred_df['speed']).numpy()
print(f'mse angle: {angle_mse}\nmse speed: {speed_mse}')
# Out:
# mse angle: 0.01459540892392397
# mse speed: 0.010389871895313263

# %%
total_mse = angle_mse + speed_mse
print(f'Total mse: {total_mse}')
# Out:
# Total mse: 0.024985279887914658

# %%
pred_df_rnd = pred_df.round({'angle': 4,'speed': 0})
pred_df_rnd.head()
# Out:
#    image_id   angle  speed
# 0         1  0.6069    1.0
# 1         2  0.3821    1.0
# 2         3  0.6381    1.0
# 3         4  0.6063    0.0
# 4         5  0.4232    0.0

# %%
angle_mse = mse(X_valid['angle'], pred_df_rnd['angle']).numpy()
speed_mse = mse(X_valid['speed'], pred_df_rnd['speed']).numpy()
print(f'mse angle: {angle_mse}\nmse speed: {speed_mse}')
# Out:
# mse angle: 0.014595293439924717
# mse speed: 0.012685755267739296

# %%
total_mse = angle_mse + speed_mse
print(f'Total mse: {total_mse}')
# Out:
# Total mse: 0.027281049638986588

# %%
pred_df_rnd['speed'] = pd.to_numeric(pred_df_rnd['speed'],downcast="integer" )
pred_df_rnd.head()
# Out:
#    image_id   angle  speed
# 0         1  0.6069      1
# 1         2  0.3821      1
# 2         3  0.6381      1
# 3         4  0.6063      0
# 4         5  0.4232      0

# %%
X_valid['speed']=X_valid['speed'].astype("int")
X_valid.head()
# Out:
#         angle  speed                                           images
# 7655   0.6250      1   ../datasets/PiCar/train/training_data/7659.png
# 7245   0.3750      1   ../datasets/PiCar/train/training_data/7249.png
# 5377   0.7500      1   ../datasets/PiCar/train/training_data/5381.png
# 13017  0.7500      0  ../datasets/PiCar/train/training_data/13023.png
# 9111   0.4375      0   ../datasets/PiCar/train/training_data/9116.png

# %%
cm = confusion_matrix(X_valid['speed'], pred_df_rnd['speed'])

# %%
# Plot confusion matrix
fig, ax = plt.subplots(figsize=(3,3))
ax.matshow(cm, cmap=plt.cm.Blues, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i, s=cm[i,j], va='center', ha='center')
classes=["1", "0"]
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)
plt.xlabel('Predicted Values',)
plt.ylabel('actual Values',);
print(classification_report(X_valid['speed'], pred_df_rnd['speed']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       643
#            1       0.99      0.99      0.99      2116
#
#     accuracy                           0.99      2759
#    macro avg       0.98      0.98      0.98      2759
# weighted avg       0.99      0.99      0.99      2759

# %%
# Plot the rciever opertaing characteristic curve (ROC)
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(10,8))
#probas_ = model.predict(X_valid['speed'])
fpr, tpr, thresholds = roc_curve(X_valid['speed'], pred_df['speed'])
roc_auc = auc(fpr,tpr)
plt.plot(fpr,tpr, lw=1, label='ROC fold (area = %0.2f)' %(roc_auc))
plt.plot([0, 1], [0, 1], '--', color=(0.6, 0.6, 0.6), label='Random')
plt.xlim([-0.05,1.05])
plt.ylim([-0.05,1.05])
plt.xlabel('False positive rate | 1 - specificity (1 -  recall)')
plt.ylabel('True positive rate | Sensitivity ( recall)')
plt.title('Reciever operating characteristics')
plt.legend(loc="lower right")
plt.axes().set_aspect(1);

# %% [markdown]
# # Testing

# %%
images_dir = '../datasets/PiCar/test'
file_list = os.listdir(images_dir)
image_paths = []
pattern = "*.png"

for filename in file_list:
    if fnmatch.fnmatch(filename, pattern):
        image_paths.append(os.path.join(images_dir,filename))

image_paths = natsorted(image_paths)

images = pd.DataFrame (image_paths, columns = ['images'])
images.describe()
# Out:
#                               images
# count                           1020
# unique                          1020
# top     ../datasets/PiCar/test/1.png
# freq                               1

# %%
def test_generator(df, batch_size, target_size):
    while True:

        for i in range(0, len(df), batch_size):
            batch = df
            # Load images and labels
            images = []
            for _, row in batch.iterrows():
                img = cv2.imread(row['images'])
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, target_size)
                images.append(img)

            images = np.array(images) / 255.0

            yield images

# %%
from keras.models import load_model
model = load_model('model/VGG16_CNN')
testgen = next(test_generator(images, batch_size=1020, target_size=(224, 224)))
predict = model.predict(testgen)
print(predict)
# Out:
# 32/32 [==============================] - 2s 59ms/step
# (array([[0.4701935 ],
#        [0.69952273],
#        [0.16464736],
#        ...,
#        [0.35066307],
#        [0.25652134],
#        [0.08131767]], dtype=float32), array([[4.8308780e-06],
#        [9.9996638e-01],
#        [9.9909163e-01],
#        ...,
#        [9.9998760e-01],
#        [9.9987006e-01],
#        [9.9907815e-01]], dtype=float32))

# %%
angles = pd.DataFrame(predict[0], columns=['Angle'])
speed = pd.DataFrame(predict[1], columns=['speed'])
pred_df = pd.concat([angles, speed],axis=1)
pred_df.insert(0,"image_id", np.arange(1,len(pred_df)+1))

pred_df.head()
# Out:
#    image_id     Angle     speed
# 0         1  0.470194  0.000005
# 1         2  0.699523  0.999966
# 2         3  0.164647  0.999092
# 3         4  0.089324  0.998976
# 4         5  0.101690  0.999283

# %%
pred_df = pred_df.round({'Angle': 4})
pred_df.head()
# Out:
#    image_id   Angle     speed
# 0         1  0.4702  0.000005
# 1         2  0.6995  0.999966
# 2         3  0.1646  0.999092
# 3         4  0.0893  0.998976
# 4         5  0.1017  0.999283

# %%
pred_df.to_csv('Tow_mat_VGG16.csv', index=False)

# %%
test = next(custom_generator(X_valid, batch_size=10, target_size=(240, 120), is_training=False))

# %%
predict_test = model.predict(test[0])
# Out:
# 1/1 [==============================] - 0s 18ms/step

# %%
print(predict_test[0])
# Out:
# [[0.5511235 ]
#  [0.7568309 ]
#  [0.7777829 ]
#  [0.72114545]
#  [0.4993554 ]
#  [0.54714364]
#  [0.47722927]
#  [0.5665439 ]
#  [0.6199493 ]
#  [0.7158552 ]]

# %%
print(test[1])
# Out:
# {'output_1': array([0.625 , 0.75  , 0.6875, 0.6875, 0.5   , 0.5   , 0.5   , 0.5625,
#        0.625 , 0.6875]), 'output_2': array([1., 1., 0., 0., 1., 1., 1., 0., 1., 0.])}
